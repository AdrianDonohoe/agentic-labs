# %%
from pydantic import BaseModel, Field
import os, sqlite3, json
from dotenv import load_dotenv
from openai import OpenAI
from langsmith.wrappers import wrap_openai
from langsmith import traceable
from openai import pydantic_function_tool
load_dotenv()

# read in env variables
#api_key = os.getenv("OLLAMA_API_KEY")
#api_base = os.getenv("OLLAMA_API_BASE")
#model = os.getenv("QWEN3_API_MODEL")

api_key = os.getenv("GEMINI_API_KEY")
api_base = os.getenv("GEMINI_API_BASE")
model = os.getenv("GEMINI_API_MODEL")

# %%
client = wrap_openai(OpenAI(
 api_key=api_key,
 base_url=api_base,
))

# %%
class Album(BaseModel):
    index: int = Field(description="The database index of the album")
    year: int = Field(description="The year the album was released")
    title: str = Field(description="The title of the album")
    artist: str = Field(description="The name of the artist who made the album")
    genre: str = Field(description="The music genre of the album")
    subgenre: str = Field(description="The music subgenre of the album")
    price: float = Field(description="The orice of the album")

class AlbumList(BaseModel):
    albums: list[Album]

# %%
class getAlbumByTitle(BaseModel):
    """Tool that queries albums by title and returns an Album object containing the database index, Album Year, Album Title, Artist Name, Album Genre, Album Subgenre  and Album Price"""
    albumTitle: str = Field(description="The title of the album.")

    def run(self):
        try:
            with sqlite3.connect('music.db') as connection:
                cursor = connection.cursor()

                sql_query = "SELECT * FROM music WHERE album = ?"

                cursor.execute(sql_query,[self.albumTitle])
                result = cursor.fetchone()

                if result is None:
                    return "No album found with that title"

                keys = ['index','year','title','artist','genre','subgenre','price']
                vals = list(result)

                result_dict = dict(zip(keys, vals))

                album = Album(**result_dict)

                return album.model_dump_json()


        #print("Database connection closed successfully!")
        except sqlite3.IntegrityError as e:
            print(f"Error: Integrity constraint violated - {e}")

        except sqlite3.OperationalError as e:
            print(f"Error: Operational issue - {e}")

        except sqlite3.Error as e:
            print(f"Error: Generic Sqlite3 error - {e}")        

        except Exception as e:
            print(f"An unexpected error occurred: {e}")

# %%
class getAlbumByArtist(BaseModel):
    """Tool that queries albums by Artist and returns a list of  Album objects containing the database index, Album Year, Album Title, Artist Name, Album Genre, Album Subgenre  and Album Price"""
    albumArtist: str = Field(description="The Artist name.")

    def run(self):
        try:
            with sqlite3.connect('music.db') as connection:
                cursor = connection.cursor()

                #sql_query = "SELECT * FROM music WHERE artist = '%s'" % self.albumArtist
                sql_query = "SELECT * FROM music WHERE artist LIKE ?"

                cursor.execute(sql_query,['%' + self.albumArtist + '%'])
                results = cursor.fetchall()
                #print(f"Results from get album by artist : {results}")

                albums = []

                for result in results:
                    keys = ['index','year','title','artist','genre','subgenre','price']
                    vals = list(result)

                    result_dict = dict(zip(keys, vals))

                    album = Album(**result_dict)
                    albums.append(album.model_dump_json())
                    print(f"Albums returned by Artist: {albums}")

                return albums


        #print("Database connection closed successfully!")
        except sqlite3.IntegrityError as e:
            print(f"Error: Integrity constraint violated - {e}")

        except sqlite3.OperationalError as e:
            print(f"Error: Operational issue - {e}")

        except sqlite3.Error as e:
            print(f"Error: Generic Sqlite3 error - {e}")        

        except Exception as e:
            print(f"An unexpected error occurred: {e}")

# %%
class getAlbumByYear(BaseModel):
    """Tool that queries albums by Year and returns a list of  Album objects containing the database index, Album Year, Album Title, Artist Name, Album Genre, Album Subgenre  and Album Price"""
    albumYear: str = Field(description="The Year.")

    def run(self):
        try:
            with sqlite3.connect('music.db') as connection:
                cursor = connection.cursor()

                sql_query = "SELECT * FROM music WHERE year = ?"

                cursor.execute(sql_query, [self.albumYear])
                results = cursor.fetchall()

                albums = []

                for result in results:
                    keys = ['index','year','title','artist','genre','subgenre','price']
                    vals = list(result)

                    result_dict = dict(zip(keys, vals))

                    album = Album(**result_dict)
                    albums.append(album.model_dump_json())

                return albums


        #print("Database connection closed successfully!")
        except sqlite3.IntegrityError as e:
            print(f"Error: Integrity constraint violated - {e}")

        except sqlite3.OperationalError as e:
            print(f"Error: Operational issue - {e}")

        except sqlite3.Error as e:
            print(f"Error: Generic Sqlite3 error - {e}")        

        except Exception as e:
            print(f"An unexpected error occurred: {e}")

# %%
class getAlbumByGenre(BaseModel):
    """Tool that queries albums by Genre and returns a list of  Album objects containing the database index, Album Year, Album Title, Artist Name, Album Genre, Album Subgenre  and Album Price"""
    albumGenre: str = Field(description="The Album Genre name.")

    def run(self):
        try:
            with sqlite3.connect('music.db') as connection:
                cursor = connection.cursor()

                sql_query = "SELECT * FROM music WHERE genre LIKE ? OR subgenre LIKE ?"

                cursor.execute(sql_query, ['%'+self.albumGenre+'%', '%'+self.albumGenre+'%'])
                results = cursor.fetchall()
                print(results)

                albums = []

                for result in results:
                    keys = ['index','year','title','artist','genre','subgenre','price']
                    vals = list(result)

                    result_dict = dict(zip(keys, vals))

                    album = Album(**result_dict)
                    albums.append(album.model_dump_json())

                return albums


        #print("Database connection closed successfully!")
        except sqlite3.IntegrityError as e:
            print(f"Error: Integrity constraint violated - {e}")

        except sqlite3.OperationalError as e:
            print(f"Error: Operational issue - {e}")

        except sqlite3.Error as e:
            print(f"Error: Generic Sqlite3 error - {e}")        

        except Exception as e:
            print(f"An unexpected error occurred: {e}")

# %%
class getAlbumByGenreAndYear(BaseModel):
    """Tool that queries albums by Genre and Year and returns a list of  Album objects containing the database index, Album Year, Album Title, Artist Name, Album Genre, Album Subgenre  and Album Price"""
    albumGenre: str = Field(description="The Album Genre name.")
    albumYear: str = Field(description="The Year.")

    def run(self):
        try:
            with sqlite3.connect('music.db') as connection:
                cursor = connection.cursor()

                sql_query = "SELECT * FROM music WHERE genre = ? and year=?"

                cursor.execute(sql_query, [self.albumGenre, self.albumYear])
                results = cursor.fetchall()
                print(results)

                albums = []

                for result in results:
                    keys = ['index','year','title','artist','genre','subgenre','price']
                    vals = list(result)

                    result_dict = dict(zip(keys, vals))

                    album = Album(**result_dict)
                    albums.append(album.model_dump_json())

                return albums


        #print("Database connection closed successfully!")
        except sqlite3.IntegrityError as e:
            print(f"Error: Integrity constraint violated - {e}")

        except sqlite3.OperationalError as e:
            print(f"Error: Operational issue - {e}")

        except sqlite3.Error as e:
            print(f"Error: Generic Sqlite3 error - {e}")        

        except Exception as e:
            print(f"An unexpected error occurred: {e}")

# %%
import csv
class writeToCsv(BaseModel):
    """Tool that writes to a csv file"""
    customerQuery: str = Field(description="The customer query.")
    queryAnswer: str = Field(description="The answer to the customer query.")

    def run(self):
        try:
            with open('email_output.csv','a', encoding='UTF8') as f:
                writer = csv.writer(f)
                data = [self.customerQuery, self.queryAnswer, 'yes']
                writer.writerow(data)
            print(f"PRINTING FROM CSV Writer:  {self.queryAnswer}")
            return self.queryAnswer
   

        except Exception as e:
            print(f"An unexpected error occurred: {e}")

# %%
# write function to execute tool. Take function name and parameters and return result of function
@traceable(name="AD Tool Call")
def execute_function(tool_call, tool_lookup):
    function_name = tool_call.function.name
    args = json.loads(tool_call.function.arguments)
    tool = tool_lookup[function_name](**args)
    return function_name, tool.run()

# %%
@traceable(name="Albums Workflow")
def albumWorkflow(customerQuery: str):

    tools = [getAlbumByTitle, getAlbumByArtist, getAlbumByGenre, getAlbumByYear, getAlbumByGenreAndYear, writeToCsv]
    tool_lookup = {tool.__name__: tool for tool in tools}
    # message to read file
    messages = [
        {"role": "system", "content": "You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file"},
        {"role": "user", "content": customerQuery}

    ]

    response = client.chat.completions.create (
    model=model,
    messages=messages,
    temperature=0,
    tools=[pydantic_function_tool(tool) for tool in tools]
    )
    #print(f"Initial response: {response}")

    if not response.choices[0].message.tool_calls:
        # No tool calls needed, return direct response
        print("SURELEY NOT RETURNING HERE")
        return response
    
    tool_calls = response.choices[0].message.tool_calls
    #print(f"Tools to run: {tool_calls}")

    # Add the assistant's message with tool calls
    messages.append({
        "role": "assistant",
        "content": response.choices[0].message.content,
        "tool_calls": [
            {
                "id": tc.id,
                "type": "function",
                "function": {
                    "name": tc.function.name,
                    "arguments": tc.function.arguments
                }
            }
            for tc in tool_calls
        ]
    })

    # Execute tools
    for tool_call in tool_calls:
        function_name, tool_result = execute_function(tool_call, tool_lookup)
        
        # Add tool response to messages
        messages.append({
            "role": "tool",
            "tool_call_id": tool_call.id,
            "content": str(tool_result)  
        })

    print(f"Messages after tool calls: {messages}")


    query_response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    print(f"QUERY _RESAPONSE:  {query_response.choices[0].message.content}")
    
    messages.append({
        "role": "assistant",
        "content": query_response.choices[0].message.content
    })
    print(f"Messages after assistant append: {messages}")

    messages.append(
        {
            "role" : "user",
            "content" : "write the customer query response to a csv file"
        }
    )



    
    write_response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0,
        tools=[pydantic_function_tool(tool) for tool in tools]
    )

    if not write_response.choices[0].message.tool_calls:
        # No tool calls needed, return direct response
        print(f"WRITE RESPONSE: {write_response}")
        return write_response

    tool_calls = write_response.choices[0].message.tool_calls
    print(f"Tools to run: {tool_calls}")

    # Add the assistant's message with tool calls
    messages.append({
        "role": "assistant",
        "content": write_response.choices[0].message.content,
        "tool_calls": [
            {
                "id": tc.id,
                "type": "function",
                "function": {
                    "name": tc.function.name,
                    "arguments": tc.function.arguments
                }
            }
            for tc in tool_calls
        ]
    })

    # Execute tools
    for tool_call in tool_calls:
        function_name, tool_result = execute_function(tool_call, tool_lookup)
        
        # Add tool response to messages
        messages.append({
            "role": "tool",
            "tool_call_id": tool_call.id,
            "content": str(tool_result)  
        })

    #print(f"Messages after tool calls: {messages}")
    print(f" THE QUERY ANSWER: {query_response.choices[0].message.content}")
    print(f"RETURN TYPE: {type(query_response.choices[0].message.content)}")
    return query_response.choices[0].message.content

# %%
res = albumWorkflow('do you have the album Nevermind ?')
res
# Out:
# Messages after tool calls: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'do you have the album Nevermind ?'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-7626213736415145018', 'type': 'function', 'function': {'name': 'getAlbumByTitle', 'arguments': '{"albumTitle":"Nevermind"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-7626213736415145018', 'content': '{"index":17,"year":1991,"title":"Nevermind","artist":"Nirvana","genre":"Rock","subgenre":"Alternative Rock, Grunge","price":0.0}'}]
# QUERY _RESAPONSE:  Yes, we do have the album "Nevermind" by Nirvana. It was released in 1991 and is a classic of Alternative Rock and Grunge. The price is $0.0.
#
# Would you like me to add it to your cart or provide more information about it?
# Messages after assistant append: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'do you have the album Nevermind ?'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-7626213736415145018', 'type': 'function', 'function': {'name': 'getAlbumByTitle', 'arguments': '{"albumTitle":"Nevermind"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-7626213736415145018', 'content': '{"index":17,"year":1991,"title":"Nevermind","artist":"Nirvana","genre":"Rock","subgenre":"Alternative Rock, Grunge","price":0.0}'}, {'role': 'assistant', 'content': 'Yes, we do have the album "Nevermind" by Nirvana. It was released in 1991 and is a classic of Alternative Rock and Grunge. The price is $0.0.\n\nWould you like me to add it to your cart or provide more information about it?'}]
# Tools to run: [ChatCompletionMessageFunctionToolCall(id='function-call-8748972962124691848', function=Function(arguments='{"customerQuery":"do you have the album Nevermind ?","queryAnswer":"Yes, we do have the album \\"Nevermind\\" by Nirvana. It was released in 1991 and is a classic of Alternative Rock and Grunge. The price is $0.0."}', name='writeToCsv'), type='function')]
# PRINTING FROM CSV Writer:  Yes, we do have the album "Nevermind" by Nirvana. It was released in 1991 and is a classic of Alternative Rock and Grunge. The price is $0.0.
#  THE QUERY ANSWER: Yes, we do have the album "Nevermind" by Nirvana. It was released in 1991 and is a classic of Alternative Rock and Grunge. The price is $0.0.
#
# Would you like me to add it to your cart or provide more information about it?
# RETURN TYPE: <class 'str'>
# 'Yes, we do have the album "Nevermind" by Nirvana. It was released in 1991 and is a classic of Alternative Rock and Grunge. The price is $0.0.\n\nWould you like me to add it to your cart or provide more information about it?'

# %%
res = albumWorkflow('do you have any bowie or led zep?')
res
# Out:
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}']
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}']
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}']
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}', '{"index":279,"year":1973,"title":"Aladdin Sane","artist":"David Bowie","genre":"Rock","subgenre":"Glam","price":0.0}']
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}', '{"index":279,"year":1973,"title":"Aladdin Sane","artist":"David Bowie","genre":"Rock","subgenre":"Glam","price":0.0}', '{"index":324,"year":1976,"title":"Station to Station","artist":"David Bowie","genre":"Rock, Funk / Soul","subgenre":"Classic Rock, Soul, Funk, Art Rock","price":0.0}']
# Albums returned by Artist: ['{"index":29,"year":1969,"title":"Led Zeppelin","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Hard Rock","price":0.0}']
# Albums returned by Artist: ['{"index":29,"year":1969,"title":"Led Zeppelin","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Hard Rock","price":0.0}', '{"index":69,"year":1971,"title":"[Led Zeppelin IV]","artist":"Led Zeppelin","genre":"Rock","subgenre":"Hard Rock, Classic Rock, Blues Rock","price":0.0}']
# Albums returned by Artist: ['{"index":29,"year":1969,"title":"Led Zeppelin","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Hard Rock","price":0.0}', '{"index":69,"year":1971,"title":"[Led Zeppelin IV]","artist":"Led Zeppelin","genre":"Rock","subgenre":"Hard Rock, Classic Rock, Blues Rock","price":0.0}', '{"index":73,"year":1975,"title":"Physical Graffiti","artist":"Led Zeppelin","genre":"Rock","subgenre":"Classic Rock","price":0.0}']
# Albums returned by Artist: ['{"index":29,"year":1969,"title":"Led Zeppelin","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Hard Rock","price":0.0}', '{"index":69,"year":1971,"title":"[Led Zeppelin IV]","artist":"Led Zeppelin","genre":"Rock","subgenre":"Hard Rock, Classic Rock, Blues Rock","price":0.0}', '{"index":73,"year":1975,"title":"Physical Graffiti","artist":"Led Zeppelin","genre":"Rock","subgenre":"Classic Rock","price":0.0}', '{"index":79,"year":1969,"title":"Led Zeppelin II","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Classic Rock, Hard Rock","price":0.0}']
# Albums returned by Artist: ['{"index":29,"year":1969,"title":"Led Zeppelin","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Hard Rock","price":0.0}', '{"index":69,"year":1971,"title":"[Led Zeppelin IV]","artist":"Led Zeppelin","genre":"Rock","subgenre":"Hard Rock, Classic Rock, Blues Rock","price":0.0}', '{"index":73,"year":1975,"title":"Physical Graffiti","artist":"Led Zeppelin","genre":"Rock","subgenre":"Classic Rock","price":0.0}', '{"index":79,"year":1969,"title":"Led Zeppelin II","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Classic Rock, Hard Rock","price":0.0}', '{"index":148,"year":1973,"title":"Houses of the Holy","artist":"Led Zeppelin","genre":"Rock","subgenre":"Classic Rock","price":0.0}']
# Messages after tool calls: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'do you have any bowie or led zep?'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-2845263018752796318', 'type': 'function', 'function': {'name': 'getAlbumByArtist', 'arguments': '{"albumArtist":"Bowie"}'}}, {'id': 'function-call-2845263018752796159', 'type': 'function', 'function': {'name': 'getAlbumByArtist', 'arguments': '{"albumArtist":"led zep"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-2845263018752796318', 'content': '[\'{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}\', \'{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}\', \'{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}\', \'{"index":279,"year":1973,"title":"Aladdin Sane","artist":"David Bowie","genre":"Rock","subgenre":"Glam","price":0.0}\', \'{"index":324,"year":1976,"title":"Station to Station","artist":"David Bowie","genre":"Rock, Funk / Soul","subgenre":"Classic Rock, Soul, Funk, Art Rock","price":0.0}\']'}, {'role': 'tool', 'tool_call_id': 'function-call-2845263018752796159', 'content': '[\'{"index":29,"year":1969,"title":"Led Zeppelin","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Hard Rock","price":0.0}\', \'{"index":69,"year":1971,"title":"[Led Zeppelin IV]","artist":"Led Zeppelin","genre":"Rock","subgenre":"Hard Rock, Classic Rock, Blues Rock","price":0.0}\', \'{"index":73,"year":1975,"title":"Physical Graffiti","artist":"Led Zeppelin","genre":"Rock","subgenre":"Classic Rock","price":0.0}\', \'{"index":79,"year":1969,"title":"Led Zeppelin II","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Classic Rock, Hard Rock","price":0.0}\', \'{"index":148,"year":1973,"title":"Houses of the Holy","artist":"Led Zeppelin","genre":"Rock","subgenre":"Classic Rock","price":0.0}\']'}]
# QUERY _RESAPONSE:  Yes, we have several albums by both David Bowie and Led Zeppelin in stock!
#
# For **David Bowie**, we have:
# *   The Rise and Fall of Ziggy Stardust and the Spiders From Mars (1972)
# *   Hunky Dory (1971)
# *   Low (1977)
# *   Aladdin Sane (1973)
# *   Station to Station (1976)
#
# And for **Led Zeppelin**, we have:
# *   Led Zeppelin (1969)
# *   [Led Zeppelin IV] (1971)
# *   Physical Graffiti (1975)
# *   Led Zeppelin II (1969)
# *   Houses of the Holy (1973)
#
# I'll also save this information to a CSV file for you.
# Messages after assistant append: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'do you have any bowie or led zep?'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-2845263018752796318', 'type': 'function', 'function': {'name': 'getAlbumByArtist', 'arguments': '{"albumArtist":"Bowie"}'}}, {'id': 'function-call-2845263018752796159', 'type': 'function', 'function': {'name': 'getAlbumByArtist', 'arguments': '{"albumArtist":"led zep"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-2845263018752796318', 'content': '[\'{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}\', \'{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}\', \'{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}\', \'{"index":279,"year":1973,"title":"Aladdin Sane","artist":"David Bowie","genre":"Rock","subgenre":"Glam","price":0.0}\', \'{"index":324,"year":1976,"title":"Station to Station","artist":"David Bowie","genre":"Rock, Funk / Soul","subgenre":"Classic Rock, Soul, Funk, Art Rock","price":0.0}\']'}, {'role': 'tool', 'tool_call_id': 'function-call-2845263018752796159', 'content': '[\'{"index":29,"year":1969,"title":"Led Zeppelin","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Hard Rock","price":0.0}\', \'{"index":69,"year":1971,"title":"[Led Zeppelin IV]","artist":"Led Zeppelin","genre":"Rock","subgenre":"Hard Rock, Classic Rock, Blues Rock","price":0.0}\', \'{"index":73,"year":1975,"title":"Physical Graffiti","artist":"Led Zeppelin","genre":"Rock","subgenre":"Classic Rock","price":0.0}\', \'{"index":79,"year":1969,"title":"Led Zeppelin II","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Classic Rock, Hard Rock","price":0.0}\', \'{"index":148,"year":1973,"title":"Houses of the Holy","artist":"Led Zeppelin","genre":"Rock","subgenre":"Classic Rock","price":0.0}\']'}, {'role': 'assistant', 'content': "Yes, we have several albums by both David Bowie and Led Zeppelin in stock!\n\nFor **David Bowie**, we have:\n*   The Rise and Fall of Ziggy Stardust and the Spiders From Mars (1972)\n*   Hunky Dory (1971)\n*   Low (1977)\n*   Aladdin Sane (1973)\n*   Station to Station (1976)\n\nAnd for **Led Zeppelin**, we have:\n*   Led Zeppelin (1969)\n*   [Led Zeppelin IV] (1971)\n*   Physical Graffiti (1975)\n*   Led Zeppelin II (1969)\n*   Houses of the Holy (1973)\n\nI'll also save this information to a CSV file for you."}]
# Tools to run: [ChatCompletionMessageFunctionToolCall(id='function-call-954617191297555364', function=Function(arguments='{"queryAnswer":"Yes, we have several albums by both David Bowie and Led Zeppelin in stock!\\n\\nFor David Bowie, we have:\\n*   The Rise and Fall of Ziggy Stardust and the Spiders From Mars (1972)\\n*   Hunky Dory (1971)\\n*   Low (1977)\\n*   Aladdin Sane (1973)\\n*   Station to Station (1976)\\n\\nAnd for Led Zeppelin, we have:\\n*   Led Zeppelin (1969)\\n*   [Led Zeppelin IV] (1971)\\n*   Physical Graffiti (1975)\\n*   Led Zeppelin II (1969)\\n*   Houses of the Holy (1973)","customerQuery":"do you have any bowie or led zep?"}', name='writeToCsv'), type='function')]
# PRINTING FROM CSV Writer:  Yes, we have several albums by both David Bowie and Led Zeppelin in stock!
#
# For David Bowie, we have:
# *   The Rise and Fall of Ziggy Stardust and the Spiders From Mars (1972)
# *   Hunky Dory (1971)
# *   Low (1977)
# *   Aladdin Sane (1973)
# *   Station to Station (1976)
#
# And for Led Zeppelin, we have:
# *   Led Zeppelin (1969)
# *   [Led Zeppelin IV] (1971)
# *   Physical Graffiti (1975)
# *   Led Zeppelin II (1969)
# *   Houses of the Holy (1973)
#  THE QUERY ANSWER: Yes, we have several albums by both David Bowie and Led Zeppelin in stock!
#
# For **David Bowie**, we have:
# *   The Rise and Fall of Ziggy Stardust and the Spiders From Mars (1972)
# *   Hunky Dory (1971)
# *   Low (1977)
# *   Aladdin Sane (1973)
# *   Station to Station (1976)
#
# And for **Led Zeppelin**, we have:
# *   Led Zeppelin (1969)
# *   [Led Zeppelin IV] (1971)
# *   Physical Graffiti (1975)
# *   Led Zeppelin II (1969)
# *   Houses of the Holy (1973)
#
# I'll also save this information to a CSV file for you.
# RETURN TYPE: <class 'str'>
# "Yes, we have several albums by both David Bowie and Led Zeppelin in stock!\n\nFor **David Bowie**, we have:\n*   The Rise and Fall of Ziggy Stardust and the Spiders From Mars (1972)\n*   Hunky Dory (1971)\n*   Low (1977)\n*   Aladdin Sane (1973)\n*   Station to Station (1976)\n\nAnd for **Led Zeppelin**, we have:\n*   Led Zeppelin (1969)\n*   [Led Zeppelin IV] (1971)\n*   Physical Graffiti (1975)\n*   Led Zeppelin II (1969)\n*   Houses of the Holy (1973)\n\nI'll also save this information to a CSV file for you."

# %%
res = albumWorkflow('Do you have any David Bowie albums available? Cheers Tom')
res
# Out:
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}']
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}']
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}']
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}', '{"index":279,"year":1973,"title":"Aladdin Sane","artist":"David Bowie","genre":"Rock","subgenre":"Glam","price":0.0}']
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}', '{"index":279,"year":1973,"title":"Aladdin Sane","artist":"David Bowie","genre":"Rock","subgenre":"Glam","price":0.0}', '{"index":324,"year":1976,"title":"Station to Station","artist":"David Bowie","genre":"Rock, Funk / Soul","subgenre":"Classic Rock, Soul, Funk, Art Rock","price":0.0}']
# Messages after tool calls: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'Do you have any David Bowie albums available? Cheers Tom'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-9456881515536502199', 'type': 'function', 'function': {'name': 'getAlbumByArtist', 'arguments': '{"albumArtist":"David Bowie"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-9456881515536502199', 'content': '[\'{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}\', \'{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}\', \'{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}\', \'{"index":279,"year":1973,"title":"Aladdin Sane","artist":"David Bowie","genre":"Rock","subgenre":"Glam","price":0.0}\', \'{"index":324,"year":1976,"title":"Station to Station","artist":"David Bowie","genre":"Rock, Funk / Soul","subgenre":"Classic Rock, Soul, Funk, Art Rock","price":0.0}\']'}]
# QUERY _RESAPONSE:  None
# Messages after assistant append: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'Do you have any David Bowie albums available? Cheers Tom'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-9456881515536502199', 'type': 'function', 'function': {'name': 'getAlbumByArtist', 'arguments': '{"albumArtist":"David Bowie"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-9456881515536502199', 'content': '[\'{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}\', \'{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}\', \'{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}\', \'{"index":279,"year":1973,"title":"Aladdin Sane","artist":"David Bowie","genre":"Rock","subgenre":"Glam","price":0.0}\', \'{"index":324,"year":1976,"title":"Station to Station","artist":"David Bowie","genre":"Rock, Funk / Soul","subgenre":"Classic Rock, Soul, Funk, Art Rock","price":0.0}\']'}, {'role': 'assistant', 'content': None}]
# Tools to run: [ChatCompletionMessageFunctionToolCall(id='function-call-9179795149235078569', function=Function(arguments='{"queryAnswer":"The albums available by David Bowie are: The Rise and Fall of Ziggy Stardust and the Spiders From Mars, Hunky Dory, Low, Aladdin Sane, Station to Station.","customerQuery":"Do you have any David Bowie albums available? Cheers Tom"}', name='writeToCsv'), type='function')]
# PRINTING FROM CSV Writer:  The albums available by David Bowie are: The Rise and Fall of Ziggy Stardust and the Spiders From Mars, Hunky Dory, Low, Aladdin Sane, Station to Station.
#  THE QUERY ANSWER: None
# RETURN TYPE: <class 'NoneType'>

# %%
res = albumWorkflow('What rock albums do you have from the early 70s?')
res
# Out:
# [(23, 1970, 'John Lennon/Plastic Ono Band', 'John Lennon / Plastic Ono Band', 'Rock', 'Pop Rock', 0.0), (51, 1970, 'Bridge Over Troubled Water', 'Simon & Garfunkel', 'Rock', 'Folk Rock, Classic Rock', 0.0), (74, 1970, 'After the Gold Rush', 'Neil Young', 'Rock', 'Rock & Roll, Country Rock', 0.0), (104, 1970, 'Sweet Baby James', 'James Taylor', 'Rock', 'Folk Rock, Acoustic, Soft Rock', 0.0), (110, 1970, 'Loaded', 'The Velvet Underground', 'Rock', 'Art Rock, Classic Rock', 0.0), (117, 1970, 'Layla and Other Assorted Love Songs', 'Derek and the Dominos', 'Rock', 'Blues Rock', 0.0), (131, 1970, 'Paranoid', 'Black Sabbath', 'Rock', 'Hard Rock, Heavy Metal', 0.0), (147, 1970, 'Deja vu', 'Crosby, Stills, Nash & Young', 'Rock', 'Classic Rock', 0.0), (170, 1970, 'Live at Leeds', 'The Who', 'Rock', 'Classic Rock, Blues Rock, Hard Rock', 0.0), (191, 1970, 'Fun House', 'The Stooges', 'Rock', 'Garage Rock, Punk', 0.0), (243, 1970, 'Black Sabbath', 'Black Sabbath', 'Rock', 'Blues Rock, Heavy Metal', 0.0), (261, 1970, 'American Beauty
', 'Rock', 'Hard Rock, Pop Rock, Prog Rock', 0.0), (292, 1975, 'The Basement Tapes', 'Bob Dylan and the Band', 'Rock', 'Folk Rock, Country Rock, Classic Rock', 0.0), (330, 1975, "Tonight's the Night", 'Neil Young', 'Rock', 'Blues Rock, Folk Rock, Classic Rock', 0.0), (374, 1975, 'Siren', 'Roxy Music', 'Rock', 'Art Rock, Pop Rock, Glam', 0.0)]
# Messages after tool calls: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'What rock albums do you have from the early 70s?'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-17447179922658429999', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumGenre":"Rock","albumYear":"1970"}'}}, {'id': 'function-call-17447179922658427606', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumGenre":"Rock","albumYear":"1971"}'}}, {'id': 'function-call-17447179922658429309', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1972","albumGenre":"Rock"}'}}, {'id': 'function-call-17447179922658426916', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumGenre":"Rock","albumYear":"1973"}'}}, {'id': 'function-call-17447179922658428619', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1974","albumGenre":"Rock"}'}}, {'id': 'function-call-17447179922658430322', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1975","albumGenre":"Rock"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-17447179922658429999', 'content': '[\'{"index":23,"year":1970,"title":"John Lennon/Plastic Ono Band","artist":"John Lennon / Plastic Ono Band","genre":"Rock","subgenre":"Pop Rock","price":0.0}\', \'{"index":51,"year":1970,"title":"Bridge Over Troubled Water","artist":"Simon & Garfunkel","genre":"Rock","subgenre":"Folk Rock, Classic Rock","price":0.0}\', \'{"index":74,"year":1970,"title":"After the Gold Rush","artist":"Neil Young","genre":"Rock","subgenre":"Rock & Roll, Country Rock","price":0.0}\', \'{"index":104,"year":1970,"title":"Sweet Baby James","artist":"James Taylor","genre":"Rock","subgenre":"Folk Rock, Acoustic, Soft Rock","price":0.0}\', \'{"index":110,"year":1970,"title":"Loaded","artist":"The Velvet Underground","genre":"Rock","subgenre":"Art Rock, Classic Rock","price":0.0}\', \'{"index":117,"year":1970,"title":"Layla and Other Assorted Love Songs","artist":"Derek and the Dominos","genre":"Rock","subgenre":"Blues Rock","price":0.0}\', \'{"index":131,"year":1970,"title":"Paranoid","artist":"Black Sabbath","genre":"Rock","subgenre":"Hard Rock, Heavy Metal","price":0.0}\', \'{"index":147,"year":1970,"title":"Deja vu","artist":"Crosby, Stills, Nash & Young","genre":"Rock","subgenre":"Classic Rock","price":0.0}\', \'{"index":170,"year":1970,"title":"Live at Leeds","artist":"The Who","genre":"Rock","subgenre":"Classic Rock, Blues Rock, Hard Rock","price":0.0}\', \'{"index":191,"year":1970,"title":"Fun House","artist":"The Stooges","genre":"Rock","subgenre":"Garage Rock, Punk","price":0.0}\', \'{"index":243,"year":1970,"title":"Black Sabbath","artist":"Black Sabbath","genre":"Rock","subgenre":"Blues Rock, Heavy Metal","price":0.0}\', \'{"index":261,"year":1970,"title":"American Beauty","artist":"Grateful Dead","genre":"Rock","subgenre":"Folk Rock","price":0.0}\', \'{"index":264,"year":1970,"title":"Workingman\\\'s Dead","artist":"Grateful Dead","genre":"Rock","subgenre":"Folk Rock, Country Rock, Classic Rock","price":0.0}\', \'{"index":392,"year":1970,"title":"Let It Be","artist":"The Beatles","genre":"Rock","subgenre":"Pop Rock","price":0.0}\', \'{"index":433,"year":1970,"title":"All Things
# **1975:**
# *   Blood on the Tracks by Bob Dylan
# *   Born to Run by Bruce Springsteen
# *   Horses by Patti Smith
# *   Physical Graffiti by Led Zeppelin
# *   Captain Fantastic and the Brown Dirt Cowboy by Elton John
# *   Alive! by KISS
# *   Wish You Were Here by Pink Floyd
# *   Toys in the Attic by Aerosmith
# *   A Night at the Opera by Queen
# *   The Basement Tapes by Bob Dylan and the Band
# *   Tonight's the Night by Neil Young
# *   Siren by Roxy Music
#
# I will also save this information to a CSV file.
# Messages after assistant append: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'What rock albums do you have from the early 70s?'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-17447179922658429999', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumGenre":"Rock","albumYear":"1970"}'}}, {'id': 'function-call-17447179922658427606', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumGenre":"Rock","albumYear":"1971"}'}}, {'id': 'function-call-17447179922658429309', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1972","albumGenre":"Rock"}'}}, {'id': 'function-call-17447179922658426916', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumGenre":"Rock","albumYear":"1973"}'}}, {'id': 'function-call-17447179922658428619', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1974","albumGenre":"Rock"}'}}, {'id': 'function-call-17447179922658430322', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1975","albumGenre":"Rock"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-17447179922658429999', 'content': '[\'{"index":23,"year":1970,"title":"John Lennon/Plastic Ono Band","artist":"John Lennon / Plastic Ono Band","genre":"Rock","subgenre":"Pop Rock","price":0.0}\', \'{"index":51,"year":1970,"title":"Bridge Over Troubled Water","artist":"Simon & Garfunkel","genre":"Rock","subgenre":"Folk Rock, Classic Rock","price":0.0}\', \'{"index":74,"year":1970,"title":"After the Gold Rush","artist":"Neil Young","genre":"Rock","subgenre":"Rock & Roll, Country Rock","price":0.0}\', \'{"index":104,"year":1970,"title":"Sweet Baby James","artist":"James Taylor","genre":"Rock","subgenre":"Folk Rock, Acoustic, Soft Rock","price":0.0}\', \'{"index":110,"year":1970,"title":"Loaded","artist":"The Velvet Underground","genre":"Rock","subgenre":"Art Rock, Classic Rock","price":0.0}\', \'{"index":117,"year":1970,"title":"Layla and Other Assorted Love Songs","artist":"Derek and the Dominos","genre":"Rock","subgenre":"Blues Rock","price":0.0}\', \'{"index":131,"year":1970,"title":"Paranoid","artist":"Black Sabbath","genre":"Rock","subgenre":"Hard Rock, Heavy Metal","price":0.0}\', \'{"index":147,"year":1970,"title":"Deja vu","artist":"Crosby, Stills, Nash & Young","genre":"Rock","subgenre":"Classic Rock","price":0.0}\', \'{"index":170,"year":1970,"title":"Live at Leeds","artist":"The Who","genre":"Rock","subgenre":"Classic Rock, Blues Rock, Hard Rock","price":0.0}\', \'{"index":191,"year":1970,"title":"Fun House","artist":"The Stooges","genre":"Rock","subgenre":"Garage Rock, Punk","price":0.0}\', \'{"index":243,"year":1970,"title":"Black Sabbath","artist":"Black Sabbath","genre":"Rock","subgenre":"Blues Rock, Heavy Metal","price":0.0}\', \'{"index":261,"year":1970,"title":"American Beauty","artist":"Grateful Dead","genre":"Rock","subgenre":"Folk Rock","price":0.0}\', \'{"index":264,"year":1970,"title":"Workingman\\\'s Dead","artist":"Grateful Dead","genre":"Rock","subgenre":"Folk Rock, Country Rock, Classic Rock","price":0.0}\', \'{"index":392,"year":1970,"title":"Let It Be","artist":"The Beatles","genre":"Rock","subgen
in-nerd) by Lynyrd Skynyrd\n*   Band on the Run by Paul McCartney & Wings\n*   Here Come the Warm Jets by Brian Eno\n*   For Everyman by Jackson Browne\n*   Tres hombres by ZZ Top\n\n**1974:**\n*   Court and Spark by Joni Mitchell\n*   Greatest Hits by Elton John\n*   Late for the Sky by Jackson Browne\n*   Radio City by Big Star\n*   461 Ocean Boulevard by Eric Clapton\n*   I Want to See the Bright Lights Tonight by Richard & Linda Thompson\n\n**1975:**\n*   Blood on the Tracks by Bob Dylan\n*   Born to Run by Bruce Springsteen\n*   Horses by Patti Smith\n*   Physical Graffiti by Led Zeppelin\n*   Captain Fantastic and the Brown Dirt Cowboy by Elton John\n*   Alive! by KISS\n*   Wish You Were Here by Pink Floyd\n*   Toys in the Attic by Aerosmith\n*   A Night at the Opera by Queen\n*   The Basement Tapes by Bob Dylan and the Band\n*   Tonight's the Night by Neil Young\n*   Siren by Roxy Music\n\nI will also save this information to a CSV file."

# %%
res = albumWorkflow('What prog rock albums do you have?')
res
# Out:
# [(28, 1971, "Who's Next", 'The Who', 'Rock', 'Hard Rock, Mod, Prog Rock, Psychedelic Rock', 0.0), (43, 1973, 'The Dark Side of the Moon', 'Pink Floyd', 'Rock', 'Prog Rock', 0.0), (87, 1979, 'The Wall', 'Pink Floyd', 'Rock', 'Alternative Rock, Prog Rock', 0.0), (173, 1972, 'Something/Anything?', 'Todd Rundgren', 'Rock', 'Power Pop, Pop Rock, Prog Rock', 0.0), (211, 1975, 'Wish You Were Here', 'Pink Floyd', 'Rock', 'Classic Rock, Prog Rock', 0.0), (231, 1975, 'A Night at the Opera', 'Queen', 'Rock', 'Hard Rock, Pop Rock, Prog Rock', 0.0), (337, 1971, 'Aqualung', 'Jethro Tull', 'Rock', 'Classic Rock, Prog Rock', 0.0)]
# Messages after tool calls: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'What prog rock albums do you have?'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-8520978407612303807', 'type': 'function', 'function': {'name': 'getAlbumByGenre', 'arguments': '{"albumGenre":"prog rock"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-8520978407612303807', 'content': '[\'{"index":28,"year":1971,"title":"Who\\\'s Next","artist":"The Who","genre":"Rock","subgenre":"Hard Rock, Mod, Prog Rock, Psychedelic Rock","price":0.0}\', \'{"index":43,"year":1973,"title":"The Dark Side of the Moon","artist":"Pink Floyd","genre":"Rock","subgenre":"Prog Rock","price":0.0}\', \'{"index":87,"year":1979,"title":"The Wall","artist":"Pink Floyd","genre":"Rock","subgenre":"Alternative Rock, Prog Rock","price":0.0}\', \'{"index":173,"year":1972,"title":"Something/Anything?","artist":"Todd Rundgren","genre":"Rock","subgenre":"Power Pop, Pop Rock, Prog Rock","price":0.0}\', \'{"index":211,"year":1975,"title":"Wish You Were Here","artist":"Pink Floyd","genre":"Rock","subgenre":"Classic Rock, Prog Rock","price":0.0}\', \'{"index":231,"year":1975,"title":"A Night at the Opera","artist":"Queen","genre":"Rock","subgenre":"Hard Rock, Pop Rock, Prog Rock","price":0.0}\', \'{"index":337,"year":1971,"title":"Aqualung","artist":"Jethro Tull","genre":"Rock","subgenre":"Classic Rock, Prog Rock","price":0.0}\']'}]
# QUERY _RESAPONSE:  Here are the progressive rock albums we have in stock:
#
# *   **Who's Next** by The Who (1971)
# *   **The Dark Side of the Moon** by Pink Floyd (1973)
# *   **The Wall** by Pink Floyd (1979)
# *   **Something/Anything?** by Todd Rundgren (1972)
# *   **Wish You Were Here** by Pink Floyd (1975)
# *   **A Night at the Opera** by Queen (1975)
# *   **Aqualung** by Jethro Tull (1971)
#
# I have also saved this information to a CSV file.
# Messages after assistant append: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'What prog rock albums do you have?'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-8520978407612303807', 'type': 'function', 'function': {'name': 'getAlbumByGenre', 'arguments': '{"albumGenre":"prog rock"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-8520978407612303807', 'content': '[\'{"index":28,"year":1971,"title":"Who\\\'s Next","artist":"The Who","genre":"Rock","subgenre":"Hard Rock, Mod, Prog Rock, Psychedelic Rock","price":0.0}\', \'{"index":43,"year":1973,"title":"The Dark Side of the Moon","artist":"Pink Floyd","genre":"Rock","subgenre":"Prog Rock","price":0.0}\', \'{"index":87,"year":1979,"title":"The Wall","artist":"Pink Floyd","genre":"Rock","subgenre":"Alternative Rock, Prog Rock","price":0.0}\', \'{"index":173,"year":1972,"title":"Something/Anything?","artist":"Todd Rundgren","genre":"Rock","subgenre":"Power Pop, Pop Rock, Prog Rock","price":0.0}\', \'{"index":211,"year":1975,"title":"Wish You Were Here","artist":"Pink Floyd","genre":"Rock","subgenre":"Classic Rock, Prog Rock","price":0.0}\', \'{"index":231,"year":1975,"title":"A Night at the Opera","artist":"Queen","genre":"Rock","subgenre":"Hard Rock, Pop Rock, Prog Rock","price":0.0}\', \'{"index":337,"year":1971,"title":"Aqualung","artist":"Jethro Tull","genre":"Rock","subgenre":"Classic Rock, Prog Rock","price":0.0}\']'}, {'role': 'assistant', 'content': "Here are the progressive rock albums we have in stock:\n\n*   **Who's Next** by The Who (1971)\n*   **The Dark Side of the Moon** by Pink Floyd (1973)\n*   **The Wall** by Pink Floyd (1979)\n*   **Something/Anything?** by Todd Rundgren (1972)\n*   **Wish You Were Here** by Pink Floyd (1975)\n*   **A Night at the Opera** by Queen (1975)\n*   **Aqualung** by Jethro Tull (1971)\n\nI have also saved this information to a CSV file."}]
# Tools to run: [ChatCompletionMessageFunctionToolCall(id='function-call-10172053508920180923', function=Function(arguments='{"queryAnswer":"Here are the progressive rock albums we have in stock:\\n\\n*   **Who\'s Next** by The Who (1971)\\n*   **The Dark Side of the Moon** by Pink Floyd (1973)\\n*   **The Wall** by Pink Floyd (1979)\\n*   **Something/Anything?** by Todd Rundgren (1972)\\n*   **Wish You Were Here** by Pink Floyd (1975)\\n*   **A Night at the Opera** by Queen (1975)\\n*   **Aqualung** by Jethro Tull (1971)\\n\\nI have also saved this information to a CSV file.","customerQuery":"What prog rock albums do you have?"}', name='writeToCsv'), type='function')]
# PRINTING FROM CSV Writer:  Here are the progressive rock albums we have in stock:
#
# *   **Who's Next** by The Who (1971)
# *   **The Dark Side of the Moon** by Pink Floyd (1973)
# *   **The Wall** by Pink Floyd (1979)
# *   **Something/Anything?** by Todd Rundgren (1972)
# *   **Wish You Were Here** by Pink Floyd (1975)
# *   **A Night at the Opera** by Queen (1975)
# *   **Aqualung** by Jethro Tull (1971)
#
# I have also saved this information to a CSV file.
#  THE QUERY ANSWER: Here are the progressive rock albums we have in stock:
#
# *   **Who's Next** by The Who (1971)
# *   **The Dark Side of the Moon** by Pink Floyd (1973)
# *   **The Wall** by Pink Floyd (1979)
# *   **Something/Anything?** by Todd Rundgren (1972)
# *   **Wish You Were Here** by Pink Floyd (1975)
# *   **A Night at the Opera** by Queen (1975)
# *   **Aqualung** by Jethro Tull (1971)
#
# I have also saved this information to a CSV file.
# RETURN TYPE: <class 'str'>
# "Here are the progressive rock albums we have in stock:\n\n*   **Who's Next** by The Who (1971)\n*   **The Dark Side of the Moon** by Pink Floyd (1973)\n*   **The Wall** by Pink Floyd (1979)\n*   **Something/Anything?** by Todd Rundgren (1972)\n*   **Wish You Were Here** by Pink Floyd (1975)\n*   **A Night at the Opera** by Queen (1975)\n*   **Aqualung** by Jethro Tull (1971)\n\nI have also saved this information to a CSV file."

# %%
import csv

# Read CSV file and print each line
with open('emails.csv', 'r') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)
    
    for line in csv_reader:
       print(line[0])
       res = albumWorkflow(line[0])  # Each line is a list of values
       res
# Out:
# Do you have any David Bowie albums available? Cheers Tom
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}']
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}']
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}']
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}', '{"index":279,"year":1973,"title":"Aladdin Sane","artist":"David Bowie","genre":"Rock","subgenre":"Glam","price":0.0}']
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}', '{"index":279,"year":1973,"title":"Aladdin Sane","artist":"David Bowie","genre":"Rock","subgenre":"Glam","price":0.0}', '{"index":324,"year":1976,"title":"Station to Station","artist":"David Bowie","genre":"Rock, Funk / Soul","subgenre":"Classic Rock, Soul, Funk, Art Rock","price":0.0}']
# Messages after tool calls: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'Do you have any David Bowie albums available? Cheers Tom'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-2279887741956474527', 'type': 'function', 'function': {'name': 'getAlbumByArtist', 'arguments': '{"albumArtist":"David Bowie"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-2279887741956474527', 'content': '[\'{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}\', \'{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}\', \'{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}\', \'{"index":279,"year":1973,"title":"Aladdin Sane","artist":"David Bowie","genre":"Rock","subgenre":"Glam","price":0.0}\', \'{"index":324,"year":1976,"title":"Station to Station","artist":"David Bowie","genre":"Rock, Funk / Soul","subgenre":"Classic Rock, Soul, Funk, Art Rock","price":0.0}\']'}]
# QUERY _RESAPONSE:  None
# Messages after assistant append: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'Do you have any David Bowie albums available? Cheers Tom'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-2279887741956474527', 'type': 'function', 'function': {'name': 'getAlbumByArtist', 'arguments': '{"albumArtist":"David Bowie"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-2279887741956474527', 'content': '[\'{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}\', \'{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}\', \'{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}\', \'{"index":279,"year":1973,"title":"Aladdin Sane","artist":"David Bowie","genre":"Rock","subgenre":"Glam","price":0.0}\', \'{"index":324,"year":1976,"title":"Station to Station","artist":"David Bowie","genre":"Rock, Funk / Soul","subgenre":"Classic Rock, Soul, Funk, Art Rock","price":0.0}\']'}, {'role': 'assistant', 'content': None}]
# Tools to run: [ChatCompletionMessageFunctionToolCall(id='function-call-17048155533789508828', function=Function(arguments='{"queryAnswer":"The albums available by David Bowie are: The Rise and Fall of Ziggy Stardust and the Spiders From Mars, Hunky Dory, Low, Aladdin Sane, Station to Station.","customerQuery":"Do you have any David Bowie albums available? Cheers Tom"}', name='writeToCsv'), type='function')]
# PRINTING FROM CSV Writer:  The albums available by David Bowie are: The Rise and Fall of Ziggy Stardust and the Spiders From Mars, Hunky Dory, Low, Aladdin Sane, Station to Station.
#  THE QUERY ANSWER: None
# RETURN TYPE: <class 'NoneType'>
# What rock albums do you have from the early 70s?
# [(113, 1974, 'Court and Spark', 'Joni Mitchell', 'Rock', 'Soft Rock, Pop Rock', 0.0), (136, 1974, 'Greatest Hits', 'Elton John', 'Rock', 'Classic Rock', 0.0), (375, 1974, 'Late for the Sky', 'Jackson Browne', 'Rock', 'Pop Rock', 0.0), (405, 1974, 'Radio City', 'Big Star', 'Rock', 'Power Pop', 0.0), (411, 1974, '461 Ocean Boulevard', 'Eric Clapton', 'Rock', 'Blues Rock', 0.0), (471, 1974, 'I Want to See the Bright Lights Tonight', 'Richard & Linda Thompson', 'Rock', 'Classic Rock, Folk Rock', 0.0)]
# [(16, 1975, 'Blood on the Tracks', 'Bob Dylan', 'Rock', 'Folk Rock, Acoustic, Ballad', 0.0), (18, 1975, 'Born to Run', 'Bruce Springsteen', 'Rock', 'Pop Rock', 0.0), (44, 1975, 'Horses', 'Patti Smith', 'Rock', 'Art Rock', 0.0), (73, 1975, 'Physical Graffiti', 'Led Zeppelin', 'Rock', 'Classic Rock', 0.0), (158, 1975, 'Captain Fantastic and the Brown Dirt Cowboy', 'Elton John', 'Rock', 'Pop Rock, Classic Rock', 0.0), (159, 1975, 'Alive!', 'KISS', 'Rock', 'Hard Rock, Glam', 0.0), (211, 1975, 'Wish You Were Here', 'Pink Floyd', 'Rock', 'Classic Rock, Prog Rock', 0.0), (229, 1975, 'Toys in the Attic', 'Aerosmith', 'Rock', 'Hard Rock, Blues Rock', 0.0), (231, 1975, 'A Night at the Opera', 'Queen', 'Rock', 'Hard Rock, Pop Rock, Prog Rock', 0.0), (292, 1975, 'The Basement Tapes', 'Bob Dylan and the Band', 'Rock', 'Folk Rock, Country Rock, Classic Rock', 0.0), (330, 1975, "Tonight's the Night", 'Neil Young', 'Rock', 'Blues Rock, Folk Rock, Classic Rock', 0.0), (374, 1975, 'Siren', 'Roxy Music', 'Rock', 'Art Rock, Pop Rock, Glam', 0.0)]
# Messages after tool calls: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'What rock albums do you have from the early 70s?'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-4482034527396731545', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1970","albumGenre":"Rock"}'}}, {'id': 'function-call-4482034527396732102', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1971","albumGenre":"Rock"}'}}, {'id': 'function-call-4482034527396732659', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1972","albumGenre":"Rock"}'}}, {'id': 'function-call-4482034527396729120', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1973","albumGenre":"Rock"}'}}, {'id': 'function-call-4482034527396729677', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1974","albumGenre":"Rock"}'}}, {'id': 'function-call-4482034527396730234', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1975","albumGenre":"Rock"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-4482034527396731545', 'content': '[\'{"index":23,"year":1970,"title":"John Lennon/Plastic Ono Band","artist":"John Lennon / Plastic Ono Band","genre":"Rock","subgenre":"Pop Rock","price":0.0}\', \'{"index":51,"year":1970,"title":"Bridge Over Troubled Water","artist":"Simon & Garfunkel","genre":"Rock","subgenre":"Folk Rock, Classic Rock","price":0.0}\', \'{"index":74,"year":1970,"title":"After the Gold Rush","artist":"Neil Young","genre":"Rock","subgenre":"Rock & Roll, Country Rock","price":0.0}\', \'{"index":104,"year":1970,"title":"Sweet Baby James","artist":"James Taylor","genre":"Rock","subgenre":"Folk Rock, Acoustic, Soft Rock","price":0.0}\', \'{"index":110,"year":1970,"title":"Loaded","artist":"The Velvet Underground","genre":"Rock","subgenre":"Art Rock, Classic Rock","price":0.0}\', \'{"index":117,"year":1970,"title":"Layla and Other Assorted Love Songs","artist":"Derek and the Dominos","genre":"Rock","subgenre":"Blues Rock","price":0.0}\', \'{"index":131,"year":1970,"title":"Paranoid","artist":"Black Sabbath","genre":"Rock","subgenre":"Hard Rock, Heavy Metal","price":0.0}\', \'{"index":147,"year":1970,"title":"Deja vu","artist":"Crosby, Stills, Nash & Young","genre":"Rock","subgenre":"Classic Rock","price":0.0}\', \'{"index":170,"year":1970,"title":"Live at Leeds","artist":"The Who","genre":"Rock","subgenre":"Classic Rock, Blues Rock, Hard Rock","price":0.0}\', \'{"index":191,"year":1970,"title":"Fun House","artist":"The Stooges","genre":"Rock","subgenre":"Garage Rock, Punk","price":0.0}\', \'{"index":243,"year":1970,"title":"Black Sabbath","artist":"Black Sabbath","genre":"Rock","subgenre":"Blues Rock, Heavy Metal","price":0.0}\', \'{"index":261,"year":1970,"title":"American Beauty","artist":"Grateful Dead","genre":"Rock","subgenre":"Folk Rock","price":0.0}\', \'{"index":264,"year":1970,"title":"Workingman\\\'s Dead","artist":"Grateful Dead","genre":"Rock","subgenre":"Folk Rock, Country Rock, Classic Rock","price":0.0}\', \'{"index":392,"year":1970,"title":"Let It Be","artist":"The Beatles","genre":"Rock","subgenre":"Pop Rock","price":0.0}\', \'{"index":433,"year":1970,"title":"All Things Must Pass","artist":"George Harrison","genre":"Rock","subgenre":"Pop Rock","price":0.0}\', \'{"index":446,"year":1970,"title":"Back in the USA","artist":"MC5","genre":"Rock","subgenre":"Garage Rock, Rock & Roll","price":0.0}\']'}, {'role': 'tool', 'tool_call_id': 'function-call-4482034527396732102', 'content': '[\'{"index":28,"year":1971,"title":"Who\\\'s Next","artist":"The Who","genre":"Rock","subgenre":"Hard Rock, Mod, Prog Rock, Psychedelic Rock","price" ...
# QUERY _RESAPONSE:  Here are some rock albums from the early 70s that we have in stock:
#
# **1970:**
# *   John Lennon/Plastic Ono Band by John Lennon / Plastic Ono Band
# *   Bridge Over Troubled Water by Simon & Garfunkel
# *   After the Gold Rush by Neil Young
# *   Sweet Baby James by James Taylor
# *   Loaded by The Velvet Underground
# *   Layla and Other Assorted Love Songs by Derek and the Dominos
# *   Paranoid by Black Sabbath
# *   Deja vu by Crosby, Stills, Nash & Young
# *   Live at Leeds by The Who
# *   Fun House by The Stooges
# *   Black Sabbath by Black Sabbath
# *   American Beauty by Grateful Dead
# *   Workingman's Dead by Grateful Dead
# *   Let It Be by The Beatles
# *   All Things Must Pass by George Harrison
# *   Back in the USA by MC5
#
# **1971:**
# *   Who's Next by The Who
# *   Sticky Fingers by The Rolling Stones
# *   [Led Zeppelin IV] by Led Zeppelin
# *   Imagine by John Lennon
# *   Hunky Dory by David Bowie
# *   Electric Warrior by T. Rex
# *   Every Picture Tells a Story by Rod Stewart
# *   Master of Reality by Black Sabbath
# *   Aqualung by Jethro Tull
# *   L.A. Woman by The Doors
# *   Love It to Death by Alice Cooper
#
# **1972:**
# *   Exile on Main St. by The Rolling Stones
# *   The Rise and Fall of Ziggy Stardust and the Spiders From Mars by David Bowie
# *   Harvest by Neil Young
# *   Something/Anything? by Todd Rundgren
# *   Transformer by Lou Reed
# *   The Kink Kronikles by The Kinks
# *   Can't Buy a Thrill by Steely Dan
# *   Paul Simon by Paul Simon
# *   Honky Ch‰teau by Elton John
# *   Eagles by Eagles
# *   #1 Record by Big Star
# *   All the Young Dudes by Mott the Hoople
# *   Give It Up by Bonnie Raitt
#
# **1973:**
# *   The Dark Side of the Moon by Pink Floyd
# *   Goodbye Yellow Brick Road by Elton John
# *   Raw Power by Iggy and The Stooges
# *   The Wild, the Innocent & the E Street Shuffle by Bruce Springsteen
# *   Houses of the Holy by Led Zeppelin
# *   New York Dolls by New York Dolls
# *   Quadrophenia by The Who
# *   Aladdin Sane by David Bowie
# *   Berlin by Lou Reed
# *   Mott by Mott the Hoople
# *   For Your Pleasure by Roxy Music
# *   (pronounced 'leh-nerd skin-nerd) by Lynyrd Skynyrd
# *   Band on the Run by Paul McCartney & Wings
# *   Here Come the Warm Jets by Brian Eno
# *   For Everyman by Jackson Browne
# *   Tres hombres by ZZ Top
#
# **1974:**
# *   Court and Spark by Joni Mitchell
# *   Greatest Hits by Elton John
# *   Late for the Sky by Jackson Browne
# *   Radio City by Big Star
# *   461 Ocean Boulevard by Eric Clapton
# *   I Want to See the Bright Lights Tonight by Richard & Linda Thompson
#
# **1975:**
# *   Blood on the Tracks by Bob Dylan
# *   Born to Run by Bruce Springsteen
# *   Horses by Patti Smith
# *   Physical Graffiti by Led Zeppelin
# *   Captain Fantastic and the Brown Dirt Cowboy by Elton John
# *   Alive! by KISS
# *   Wish You Were Here by Pink Floyd
# *   Toys in the Attic by Aerosmith
# *   A Night at the Opera by Queen
# *   The Basement Tapes by Bob Dylan and the Band
# *   Tonight's the Night by Neil Young
# *   Siren by Roxy Music
#
# I will also save this information to a CSV file.
# Messages after assistant append: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'What rock albums do you have from the early 70s?'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-4482034527396731545', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1970","albumGenre":"Rock"}'}}, {'id': 'function-call-4482034527396732102', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1971","albumGenre":"Rock"}'}}, {'id': 'function-call-4482034527396732659', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1972","albumGenre":"Rock"}'}}, {'id': 'function-call-4482034527396729120', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1973","albumGenre":"Rock"}'}}, {'id': 'function-call-4482034527396729677', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1974","albumGenre":"Rock"}'}}, {'id': 'function-call-4482034527396730234', 'type': 'function', 'function': {'name': 'getAlbumByGenreAndYear', 'arguments': '{"albumYear":"1975","albumGenre":"Rock"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-4482034527396731545', 'content': '[\'{"index":23,"year":1970,"title":"John Lennon/Plastic Ono Band","artist":"John Lennon / Plastic Ono Band","genre":"Rock","subgenre":"Pop Rock","price":0.0}\', \'{"index":51,"year":1970,"title":"Bridge Over Troubled Water","artist":"Simon & Garfunkel","genre":"Rock","subgenre":"Folk Rock, Classic Rock","price":0.0}\', \'{"index":74,"year":1970,"title":"After the Gold Rush","artist":"Neil Young","genre":"Rock","subgenre":"Rock & Roll, Country Rock","price":0.0}\', \'{"index":104,"year":1970,"title":"Sweet Baby James","artist":"James Taylor","genre":"Rock","subgenre":"Folk Rock, Acoustic, Soft Rock","price":0.0}\', \'{"index":110,"year":1970,"title":"Loaded","artist":"The Velvet Underground","genre":"Rock","subgenre":"Art Rock, Classic Rock","price":0.0}\', \'{"index":117,"year":1970,"title":"Layla and Other Assorted Love Songs","artist":"Derek and the Dominos","genre":"Rock","subgenre":"Blues Rock","price":0.0}\', \'{"index":131,"year":1970,"title":"Paranoid","artist":"Black Sabbath","genre":"Rock","subgenre":"Hard Rock, Heavy Metal","price":0.0}\', \'{"index":147,"year":1970,"title":"Deja vu","artist":"Crosby, Stills, Nash & Young","genre":"Rock","subgenre":"Classic Rock","price":0.0}\', \'{"index":170,"year":1970,"title":"Live at Leeds","artist":"The Who","genre":"Rock","subgenre":"Classic Rock, Blues Rock, Hard Rock","price":0.0}\', \'{"index":191,"year":1970,"title":"Fun House","artist":"The Stooges","genre":"Rock","subgenre":"Garage Rock, Punk","price":0.0}\', \'{"index":243,"year":1970,"title":"Black Sabbath","artist":"Black Sabbath","genre":"Rock","subgenre":"Blues Rock, Heavy Metal","price":0.0}\', \'{"index":261,"year":1970,"title":"American Beauty","artist":"Grateful Dead","genre":"Rock","subgenre":"Folk Rock","price":0.0}\', \'{"index":264,"year":1970,"title":"Workingman\\\'s Dead","artist":"Grateful Dead","genre":"Rock","subgenre":"Folk Rock, Country Rock, Classic Rock","price":0.0}\', \'{"index":392,"year":1970,"title":"Let It Be","artist":"The Beatles","genre":"Rock","subgenre":"Pop Rock","price":0.0}\', \'{"index":433,"year":1970,"title":"All Things Must Pass","artist":"George Harrison","genre":"Rock","subgenre":"Pop Rock","price":0.0}\', \'{"index":446,"year":1970,"title":"Back in the USA","artist":"MC5","genre":"Rock","subgenre":"Garage Rock, Rock & Roll","price":0.0}\']'}, {'role': 'tool', 'tool_call_id': 'function-call-4482034527396732102', 'content': '[\'{"index":28,"year":1971,"title":"Who\\\'s Next","artist":"The Who","genre":"Rock","subgenre":"Hard Rock, Mod, Prog Rock, Psychedelic Rock"," ...
# Tools to run: [ChatCompletionMessageFunctionToolCall(id='function-call-10930270667494252013', function=Function(arguments='{"customerQuery":"What rock albums do you have from the early 70s?","queryAnswer":"Here are some rock albums from the early 70s that we have in stock:\\n\\n**1970:**\\n*   John Lennon/Plastic Ono Band by John Lennon / Plastic Ono Band\\n*   Bridge Over Troubled Water by Simon & Garfunkel\\n*   After the Gold Rush by Neil Young\\n*   Sweet Baby James by James Taylor\\n*   Loaded by The Velvet Underground\\n*   Layla and Other Assorted Love Songs by Derek and the Dominos\\n*   Paranoid by Black Sabbath\\n*   Deja vu by Crosby, Stills, Nash & Young\\n*   Live at Leeds by The Who\\n*   Fun House by The Stooges\\n*   Black Sabbath by Black Sabbath\\n*   American Beauty by Grateful Dead\\n*   Workingman\'s Dead by Grateful Dead\\n*   Let It Be by The Beatles\\n*   All Things Must Pass by George Harrison\\n*   Back in the USA by MC5\\n\\n**1971:**\\n*   Who\'s Next by The Who\\n*   Sticky Fingers by The Rolling Stones\\n*   [Led Zeppelin IV] by Led Zeppelin\\n*   Imagine by John Lennon\\n*   Hunky Dory by David Bowie\\n*   Electric Warrior by T. Rex\\n*   Every Picture Tells a Story by Rod Stewart\\n*   Master of Reality by Black Sabbath\\n*   Aqualung by Jethro Tull\\n*   L.A. Woman by The Doors\
# *   Every Picture Tells a Story by Rod Stewart
# *   Master of Reality by Black Sabbath
# *   Aqualung by Jethro Tull
# *   L.A. Woman by The Doors
# *   Love It to Death by Alice Cooper
#
# **1972:**
# *   Exile on Main St. by The Rolling Stones
# *   The Rise and Fall of Ziggy Stardust and the Spiders From Mars by David Bowie
# *   Harvest by Neil Young
# *   Something/Anything? by Todd Rundgren
# *   Transformer by Lou Reed
# *   The Kink Kronikles by The Kinks
# *   Can't Buy a Thrill by Steely Dan
# *   Paul Simon by Paul Simon
# *   Honky Ch‰teau by Elton John
# *   Eagles by Eagles
# *   #1 Record by Big Star
# *   All the Young Dudes by Mott the Hoople
# *   Give It Up by Bonnie Raitt
#
# **1973:**
# *   The Dark Side of the Moon by Pink Floyd
# *   Goodbye Yellow Brick Road by Elton John
# *   Raw Power by Iggy and The Stooges
# *   The Wild, the Innocent & the E Street Shuffle by Bruce Springsteen
# *   Houses of the Holy by Led Zeppelin
# *   New York Dolls by New York Dolls
# *   Quadrophenia by The Who
# *   Aladdin Sane by David Bowie
# *   Berlin by Lou Reed
# *   Mott by Mott the Hoople
# *   For Your Pleasure by Roxy Music
# *   (pronounced 'leh-nerd skin-nerd) by Lynyrd Skynyrd
# *   Band on the Run by Paul McCartney & Wings
# *   Here Come the Warm Jets by Brian Eno
# *   For Everyman by Jackson Browne
# *   Tres hombres by ZZ Top
#
# **1974:**
# *   Court and Spark by Joni Mitchell
# *   Greatest Hits by Elton John
# *   Late for the Sky by Jackson Browne
# *   Radio City by Big Star
# *   461 Ocean Boulevard by Eric Clapton
# *   I Want to See the Bright Lights Tonight by Richard & Linda Thompson
#
# **1975:**
# *   Blood on the Tracks by Bob Dylan
# *   Born to Run by Bruce Springsteen
# *   Horses by Patti Smith
# *   Physical Graffiti by Led Zeppelin
# *   Captain Fantastic and the Brown Dirt Cowboy by Elton John
# *   Alive! by KISS
# *   Wish You Were Here by Pink Floyd
# *   Toys in the Attic by Aerosmith
# *   A Night at the Opera by Queen
# *   The Basement Tapes by Bob Dylan and the Band
# *   Tonight's the Night by Neil Young
# *   Siren by Roxy Music
#
# I will also save this information to a CSV file.
# RETURN TYPE: <class 'str'>
# What prog rock albums do you have?
# [(28, 1971, "Who's Next", 'The Who', 'Rock', 'Hard Rock, Mod, Prog Rock, Psychedelic Rock', 0.0), (43, 1973, 'The Dark Side of the Moon', 'Pink Floyd', 'Rock', 'Prog Rock', 0.0), (87, 1979, 'The Wall', 'Pink Floyd', 'Rock', 'Alternative Rock, Prog Rock', 0.0), (173, 1972, 'Something/Anything?', 'Todd Rundgren', 'Rock', 'Power Pop, Pop Rock, Prog Rock', 0.0), (211, 1975, 'Wish You Were Here', 'Pink Floyd', 'Rock', 'Classic Rock, Prog Rock', 0.0), (231, 1975, 'A Night at the Opera', 'Queen', 'Rock', 'Hard Rock, Pop Rock, Prog Rock', 0.0), (337, 1971, 'Aqualung', 'Jethro Tull', 'Rock', 'Classic Rock, Prog Rock', 0.0)]
# Messages after tool calls: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'What prog rock albums do you have?'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-9100854207338182488', 'type': 'function', 'function': {'name': 'getAlbumByGenre', 'arguments': '{"albumGenre":"prog rock"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-9100854207338182488', 'content': '[\'{"index":28,"year":1971,"title":"Who\\\'s Next","artist":"The Who","genre":"Rock","subgenre":"Hard Rock, Mod, Prog Rock, Psychedelic Rock","price":0.0}\', \'{"index":43,"year":1973,"title":"The Dark Side of the Moon","artist":"Pink Floyd","genre":"Rock","subgenre":"Prog Rock","price":0.0}\', \'{"index":87,"year":1979,"title":"The Wall","artist":"Pink Floyd","genre":"Rock","subgenre":"Alternative Rock, Prog Rock","price":0.0}\', \'{"index":173,"year":1972,"title":"Something/Anything?","artist":"Todd Rundgren","genre":"Rock","subgenre":"Power Pop, Pop Rock, Prog Rock","price":0.0}\', \'{"index":211,"year":1975,"title":"Wish You Were Here","artist":"Pink Floyd","genre":"Rock","subgenre":"Classic Rock, Prog Rock","price":0.0}\', \'{"index":231,"year":1975,"title":"A Night at the Opera","artist":"Queen","genre":"Rock","subgenre":"Hard Rock, Pop Rock, Prog Rock","price":0.0}\', \'{"index":337,"year":1971,"title":"Aqualung","artist":"Jethro Tull","genre":"Rock","subgenre":"Classic Rock, Prog Rock","price":0.0}\']'}]
# QUERY _RESAPONSE:  Here are the progressive rock albums we have in stock:
#
# *   **Who's Next** by The Who (1971)
# *   **The Dark Side of the Moon** by Pink Floyd (1973)
# *   **The Wall** by Pink Floyd (1979)
# *   **Something/Anything?** by Todd Rundgren (1972)
# *   **Wish You Were Here** by Pink Floyd (1975)
# *   **A Night at the Opera** by Queen (1975)
# *   **Aqualung** by Jethro Tull (1971)
#
# I have also saved this information to a CSV file.
# Messages after assistant append: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'What prog rock albums do you have?'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-9100854207338182488', 'type': 'function', 'function': {'name': 'getAlbumByGenre', 'arguments': '{"albumGenre":"prog rock"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-9100854207338182488', 'content': '[\'{"index":28,"year":1971,"title":"Who\\\'s Next","artist":"The Who","genre":"Rock","subgenre":"Hard Rock, Mod, Prog Rock, Psychedelic Rock","price":0.0}\', \'{"index":43,"year":1973,"title":"The Dark Side of the Moon","artist":"Pink Floyd","genre":"Rock","subgenre":"Prog Rock","price":0.0}\', \'{"index":87,"year":1979,"title":"The Wall","artist":"Pink Floyd","genre":"Rock","subgenre":"Alternative Rock, Prog Rock","price":0.0}\', \'{"index":173,"year":1972,"title":"Something/Anything?","artist":"Todd Rundgren","genre":"Rock","subgenre":"Power Pop, Pop Rock, Prog Rock","price":0.0}\', \'{"index":211,"year":1975,"title":"Wish You Were Here","artist":"Pink Floyd","genre":"Rock","subgenre":"Classic Rock, Prog Rock","price":0.0}\', \'{"index":231,"year":1975,"title":"A Night at the Opera","artist":"Queen","genre":"Rock","subgenre":"Hard Rock, Pop Rock, Prog Rock","price":0.0}\', \'{"index":337,"year":1971,"title":"Aqualung","artist":"Jethro Tull","genre":"Rock","subgenre":"Classic Rock, Prog Rock","price":0.0}\']'}, {'role': 'assistant', 'content': "Here are the progressive rock albums we have in stock:\n\n*   **Who's Next** by The Who (1971)\n*   **The Dark Side of the Moon** by Pink Floyd (1973)\n*   **The Wall** by Pink Floyd (1979)\n*   **Something/Anything?** by Todd Rundgren (1972)\n*   **Wish You Were Here** by Pink Floyd (1975)\n*   **A Night at the Opera** by Queen (1975)\n*   **Aqualung** by Jethro Tull (1971)\n\nI have also saved this information to a CSV file."}]
# Tools to run: [ChatCompletionMessageFunctionToolCall(id='function-call-4637103268589230487', function=Function(arguments='{"queryAnswer":"Here are the progressive rock albums we have in stock:\\n\\n*   **Who\'s Next** by The Who (1971)\\n*   **The Dark Side of the Moon** by Pink Floyd (1973)\\n*   **The Wall** by Pink Floyd (1979)\\n*   **Something/Anything?** by Todd Rundgren (1972)\\n*   **Wish You Were Here** by Pink Floyd (1975)\\n*   **A Night at the Opera** by Queen (1975)\\n*   **Aqualung** by Jethro Tull (1971)\\n\\nI have also saved this information to a CSV file.","customerQuery":"What prog rock albums do you have?"}', name='writeToCsv'), type='function')]
# PRINTING FROM CSV Writer:  Here are the progressive rock albums we have in stock:
#
# *   **Who's Next** by The Who (1971)
# *   **The Dark Side of the Moon** by Pink Floyd (1973)
# *   **The Wall** by Pink Floyd (1979)
# *   **Something/Anything?** by Todd Rundgren (1972)
# *   **Wish You Were Here** by Pink Floyd (1975)
# *   **A Night at the Opera** by Queen (1975)
# *   **Aqualung** by Jethro Tull (1971)
#
# I have also saved this information to a CSV file.
#  THE QUERY ANSWER: Here are the progressive rock albums we have in stock:
#
# *   **Who's Next** by The Who (1971)
# *   **The Dark Side of the Moon** by Pink Floyd (1973)
# *   **The Wall** by Pink Floyd (1979)
# *   **Something/Anything?** by Todd Rundgren (1972)
# *   **Wish You Were Here** by Pink Floyd (1975)
# *   **A Night at the Opera** by Queen (1975)
# *   **Aqualung** by Jethro Tull (1971)
#
# I have also saved this information to a CSV file.
# RETURN TYPE: <class 'str'>
# do you have any bowie or led zep?
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}']
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}']
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}']
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}', '{"index":279,"year":1973,"title":"Aladdin Sane","artist":"David Bowie","genre":"Rock","subgenre":"Glam","price":0.0}']
# Albums returned by Artist: ['{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}', '{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}', '{"index":279,"year":1973,"title":"Aladdin Sane","artist":"David Bowie","genre":"Rock","subgenre":"Glam","price":0.0}', '{"index":324,"year":1976,"title":"Station to Station","artist":"David Bowie","genre":"Rock, Funk / Soul","subgenre":"Classic Rock, Soul, Funk, Art Rock","price":0.0}']
# Albums returned by Artist: ['{"index":29,"year":1969,"title":"Led Zeppelin","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Hard Rock","price":0.0}']
# Albums returned by Artist: ['{"index":29,"year":1969,"title":"Led Zeppelin","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Hard Rock","price":0.0}', '{"index":69,"year":1971,"title":"[Led Zeppelin IV]","artist":"Led Zeppelin","genre":"Rock","subgenre":"Hard Rock, Classic Rock, Blues Rock","price":0.0}']
# Albums returned by Artist: ['{"index":29,"year":1969,"title":"Led Zeppelin","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Hard Rock","price":0.0}', '{"index":69,"year":1971,"title":"[Led Zeppelin IV]","artist":"Led Zeppelin","genre":"Rock","subgenre":"Hard Rock, Classic Rock, Blues Rock","price":0.0}', '{"index":73,"year":1975,"title":"Physical Graffiti","artist":"Led Zeppelin","genre":"Rock","subgenre":"Classic Rock","price":0.0}']
# Albums returned by Artist: ['{"index":29,"year":1969,"title":"Led Zeppelin","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Hard Rock","price":0.0}', '{"index":69,"year":1971,"title":"[Led Zeppelin IV]","artist":"Led Zeppelin","genre":"Rock","subgenre":"Hard Rock, Classic Rock, Blues Rock","price":0.0}', '{"index":73,"year":1975,"title":"Physical Graffiti","artist":"Led Zeppelin","genre":"Rock","subgenre":"Classic Rock","price":0.0}', '{"index":79,"year":1969,"title":"Led Zeppelin II","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Classic Rock, Hard Rock","price":0.0}']
# Albums returned by Artist: ['{"index":29,"year":1969,"title":"Led Zeppelin","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Hard Rock","price":0.0}', '{"index":69,"year":1971,"title":"[Led Zeppelin IV]","artist":"Led Zeppelin","genre":"Rock","subgenre":"Hard Rock, Classic Rock, Blues Rock","price":0.0}', '{"index":73,"year":1975,"title":"Physical Graffiti","artist":"Led Zeppelin","genre":"Rock","subgenre":"Classic Rock","price":0.0}', '{"index":79,"year":1969,"title":"Led Zeppelin II","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Classic Rock, Hard Rock","price":0.0}', '{"index":148,"year":1973,"title":"Houses of the Holy","artist":"Led Zeppelin","genre":"Rock","subgenre":"Classic Rock","price":0.0}']
# Messages after tool calls: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'do you have any bowie or led zep?'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-9690514987395612891', 'type': 'function', 'function': {'name': 'getAlbumByArtist', 'arguments': '{"albumArtist":"Bowie"}'}}, {'id': 'function-call-9690514987395612958', 'type': 'function', 'function': {'name': 'getAlbumByArtist', 'arguments': '{"albumArtist":"led zep"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-9690514987395612891', 'content': '[\'{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}\', \'{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}\', \'{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}\', \'{"index":279,"year":1973,"title":"Aladdin Sane","artist":"David Bowie","genre":"Rock","subgenre":"Glam","price":0.0}\', \'{"index":324,"year":1976,"title":"Station to Station","artist":"David Bowie","genre":"Rock, Funk / Soul","subgenre":"Classic Rock, Soul, Funk, Art Rock","price":0.0}\']'}, {'role': 'tool', 'tool_call_id': 'function-call-9690514987395612958', 'content': '[\'{"index":29,"year":1969,"title":"Led Zeppelin","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Hard Rock","price":0.0}\', \'{"index":69,"year":1971,"title":"[Led Zeppelin IV]","artist":"Led Zeppelin","genre":"Rock","subgenre":"Hard Rock, Classic Rock, Blues Rock","price":0.0}\', \'{"index":73,"year":1975,"title":"Physical Graffiti","artist":"Led Zeppelin","genre":"Rock","subgenre":"Classic Rock","price":0.0}\', \'{"index":79,"year":1969,"title":"Led Zeppelin II","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Classic Rock, Hard Rock","price":0.0}\', \'{"index":148,"year":1973,"title":"Houses of the Holy","artist":"Led Zeppelin","genre":"Rock","subgenre":"Classic Rock","price":0.0}\']'}]
# QUERY _RESAPONSE:  Yes, we have several albums by both David Bowie and Led Zeppelin in stock!
#
# For **David Bowie**, we have:
# *   The Rise and Fall of Ziggy Stardust and the Spiders From Mars (1972)
# *   Hunky Dory (1971)
# *   Low (1977)
# *   Aladdin Sane (1973)
# *   Station to Station (1976)
#
# And for **Led Zeppelin**, we have:
# *   Led Zeppelin (1969)
# *   [Led Zeppelin IV] (1971)
# *   Physical Graffiti (1975)
# *   Led Zeppelin II (1969)
# *   Houses of the Holy (1973)
#
# I'll also save this information to a CSV file for you.
# Messages after assistant append: [{'role': 'system', 'content': 'You are a useful music shop assistant that answers customer queries providing information on albums and writes the answer to a csv file'}, {'role': 'user', 'content': 'do you have any bowie or led zep?'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'function-call-9690514987395612891', 'type': 'function', 'function': {'name': 'getAlbumByArtist', 'arguments': '{"albumArtist":"Bowie"}'}}, {'id': 'function-call-9690514987395612958', 'type': 'function', 'function': {'name': 'getAlbumByArtist', 'arguments': '{"albumArtist":"led zep"}'}}]}, {'role': 'tool', 'tool_call_id': 'function-call-9690514987395612891', 'content': '[\'{"index":35,"year":1972,"title":"The Rise and Fall of Ziggy Stardust and the Spiders From Mars","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}\', \'{"index":108,"year":1971,"title":"Hunky Dory","artist":"David Bowie","genre":"Rock","subgenre":"Classic Rock, Glam","price":0.0}\', \'{"index":251,"year":1977,"title":"Low","artist":"David Bowie","genre":"Electronic, Rock","subgenre":"Art Rock, Ambient, Experimental","price":0.0}\', \'{"index":279,"year":1973,"title":"Aladdin Sane","artist":"David Bowie","genre":"Rock","subgenre":"Glam","price":0.0}\', \'{"index":324,"year":1976,"title":"Station to Station","artist":"David Bowie","genre":"Rock, Funk / Soul","subgenre":"Classic Rock, Soul, Funk, Art Rock","price":0.0}\']'}, {'role': 'tool', 'tool_call_id': 'function-call-9690514987395612958', 'content': '[\'{"index":29,"year":1969,"title":"Led Zeppelin","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Hard Rock","price":0.0}\', \'{"index":69,"year":1971,"title":"[Led Zeppelin IV]","artist":"Led Zeppelin","genre":"Rock","subgenre":"Hard Rock, Classic Rock, Blues Rock","price":0.0}\', \'{"index":73,"year":1975,"title":"Physical Graffiti","artist":"Led Zeppelin","genre":"Rock","subgenre":"Classic Rock","price":0.0}\', \'{"index":79,"year":1969,"title":"Led Zeppelin II","artist":"Led Zeppelin","genre":"Rock","subgenre":"Blues Rock, Classic Rock, Hard Rock","price":0.0}\', \'{"index":148,"year":1973,"title":"Houses of the Holy","artist":"Led Zeppelin","genre":"Rock","subgenre":"Classic Rock","price":0.0}\']'}, {'role': 'assistant', 'content': "Yes, we have several albums by both David Bowie and Led Zeppelin in stock!\n\nFor **David Bowie**, we have:\n*   The Rise and Fall of Ziggy Stardust and the Spiders From Mars (1972)\n*   Hunky Dory (1971)\n*   Low (1977)\n*   Aladdin Sane (1973)\n*   Station to Station (1976)\n\nAnd for **Led Zeppelin**, we have:\n*   Led Zeppelin (1969)\n*   [Led Zeppelin IV] (1971)\n*   Physical Graffiti (1975)\n*   Led Zeppelin II (1969)\n*   Houses of the Holy (1973)\n\nI'll also save this information to a CSV file for you."}]
# Tools to run: [ChatCompletionMessageFunctionToolCall(id='function-call-3329149002881298832', function=Function(arguments='{"customerQuery":"do you have any bowie or led zep?","queryAnswer":"Yes, we have several albums by both David Bowie and Led Zeppelin in stock!\\n\\nFor David Bowie, we have:\\n*   The Rise and Fall of Ziggy Stardust and the Spiders From Mars (1972)\\n*   Hunky Dory (1971)\\n*   Low (1977)\\n*   Aladdin Sane (1973)\\n*   Station to Station (1976)\\n\\nAnd for Led Zeppelin, we have:\\n*   Led Zeppelin (1969)\\n*   [Led Zeppelin IV] (1971)\\n*   Physical Graffiti (1975)\\n*   Led Zeppelin II (1969)\\n*   Houses of the Holy (1973)"}', name='writeToCsv'), type='function')]
# PRINTING FROM CSV Writer:  Yes, we have several albums by both David Bowie and Led Zeppelin in stock!
#
# For David Bowie, we have:
# *   The Rise and Fall of Ziggy Stardust and the Spiders From Mars (1972)
# *   Hunky Dory (1971)
# *   Low (1977)
# *   Aladdin Sane (1973)
# *   Station to Station (1976)
#
# And for Led Zeppelin, we have:
# *   Led Zeppelin (1969)
# *   [Led Zeppelin IV] (1971)
# *   Physical Graffiti (1975)
# *   Led Zeppelin II (1969)
# *   Houses of the Holy (1973)
#  THE QUERY ANSWER: Yes, we have several albums by both David Bowie and Led Zeppelin in stock!
#
# For **David Bowie**, we have:
# *   The Rise and Fall of Ziggy Stardust and the Spiders From Mars (1972)
# *   Hunky Dory (1971)
# *   Low (1977)
# *   Aladdin Sane (1973)
# *   Station to Station (1976)
#
# And for **Led Zeppelin**, we have:
# *   Led Zeppelin (1969)
# *   [Led Zeppelin IV] (1971)
# *   Physical Graffiti (1975)
# *   Led Zeppelin II (1969)
# *   Houses of the Holy (1973)
#
# I'll also save this information to a CSV file for you.
# RETURN TYPE: <class 'str'>
