# %%
from pydantic import BaseModel, Field
import os, sqlite3, json
from dotenv import load_dotenv
from openai import OpenAI
from langsmith.wrappers import wrap_openai
from langsmith import traceable
from openai import pydantic_function_tool
load_dotenv()

# read in env variables
#api_key = os.getenv("OLLAMA_API_KEY")
#api_base = os.getenv("OLLAMA_API_BASE")
#model = os.getenv("QWEN3_API_MODEL")

api_key = os.getenv("GEMINI_API_KEY")
api_base = os.getenv("GEMINI_API_BASE")
model = os.getenv("GEMINI_API_MODEL")

# %%
client = wrap_openai(OpenAI(
 api_key=api_key,
 base_url=api_base,
))

# %%
with sqlite3.connect('music.db') as connection:

    # Step 2: Create a cursor object to interact with the database
    cursor = connection.cursor()

    print("Database created and connected successfully!")

    sql_query = """SELECT * FROM sqlite_master;"""

    cursor.execute(sql_query)

    print(cursor.fetchall())

    print("Database connection closed successfully!")
# Out:
# Database created and connected successfully!
# [('table', 'music', 'music', 2, 'CREATE TABLE music\n        (number INTEGER, year INTEGER, album TEXT,  artist TEXT, genre TEXT, subgenre TEXT, price REAL)')]
# Database connection closed successfully!

# %%
with sqlite3.connect('music.db') as connection:

    # Step 2: Create a cursor object to interact with the database
    cursor = connection.cursor()

    print("Database created and connected successfully!")

    sql_query = """SELECT * FROM music where album='Nevermind';"""

    cursor.execute(sql_query)

    print(cursor.fetchone())

    print("Database connection closed successfully!")
# Out:
# Database created and connected successfully!
# (17, 1991, 'Nevermind', 'Nirvana', 'Rock', 'Alternative Rock, Grunge', 0.0)
# Database connection closed successfully!

# %%
with sqlite3.connect('music.db') as connection:

    # Step 2: Create a cursor object to interact with the database
    cursor = connection.cursor()

    print("Database created and connected successfully!")

    sql_query = """SELECT * FROM music where artist='The Beach Boys';"""

    cursor.execute(sql_query)

    print(cursor.fetchall())

    print("Database connection closed successfully!")
# Out:
# Database created and connected successfully!
# [(2, 1966, 'Pet Sounds', 'The Beach Boys', 'Rock', 'Pop Rock, Psychedelic Rock', 0.0), (271, 1965, 'The Beach Boys Today!', 'The Beach Boys', 'Rock', 'Pop Rock, Psychedelic Rock', 0.0), (381, 2011, 'The Smile Sessions', 'The Beach Boys', 'Rock', 'Pop Rock, Psychedelic Rock', 0.0)]
# Database connection closed successfully!

# %%
with sqlite3.connect('music.db') as connection:

    # Step 2: Create a cursor object to interact with the database
    cursor = connection.cursor()

    print("Database created and connected successfully!")

    sql_query = """SELECT * FROM music where year=1966;"""

    cursor.execute(sql_query)

    print(cursor.fetchall())

    print("Database connection closed successfully!")
# Out:
# Database created and connected successfully!
# ...

# %%
with sqlite3.connect('music.db') as connection:

    # Step 2: Create a cursor object to interact with the database
    cursor = connection.cursor()

    print("Database created and connected successfully!")

    sql_query = """SELECT * FROM music where genre='Rock';"""

    cursor.execute(sql_query)

    print(cursor.fetchall())

    print("Database connection closed successfully!")
# Out:
# Database created and connected successfully!
# ...

# %%
def getAlbumByTitle(title):
    with sqlite3.connect('music.db') as connection:
        cursor = connection.cursor()

        #print("Database created and connected successfully!")

        sql_query = "SELECT * FROM music WHERE album = '%s'" % title

        cursor.execute(sql_query)

        output = cursor.fetchone()
        return output

        #print("Database connection closed successfully!")

# %%
res = getAlbumByTitle('Pet Sounds')

# %%
type(res)
# Out:
# tuple

# %%
def getAlbumByArtist(artist):
    with sqlite3.connect('music.db') as connection:
        cursor = connection.cursor()

        #print("Database created and connected successfully!")

        sql_query = "SELECT * FROM music WHERE artist = '%s'" % artist

        cursor.execute(sql_query)

        #print(cursor.fetchall())

        output = cursor.fetchall()

        #print("Database connection closed successfully!")

        return output

# %%
getAlbumByArtist('The Beach Boys')
# Out:
# [(2,
#   1966,
#   'Pet Sounds',
#   'The Beach Boys',
#   'Rock',
#   'Pop Rock, Psychedelic Rock',
#   0.0),
#  (271,
#   1965,
#   'The Beach Boys Today!',
#   'The Beach Boys',
#   'Rock',
#   'Pop Rock, Psychedelic Rock',
#   0.0),
#  (381,
#   2011,
#   'The Smile Sessions',
#   'The Beach Boys',
#   'Rock',
#   'Pop Rock, Psychedelic Rock',
#   0.0)]

# %%
def getAlbumByYear(year):
    with sqlite3.connect('music.db') as connection:
        cursor = connection.cursor()

        print("Database created and connected successfully!")

        sql_query = "SELECT * FROM music WHERE year = '%s'" % year

        cursor.execute(sql_query)

        print(cursor.fetchall())

        print("Database connection closed successfully!")

# %%
getAlbumByYear(1966)
# Out:
# Database created and connected successfully!
# ...

# %%
def getAlbumByGenre(genre):
    try:
        with sqlite3.connect('music.db') as connection:
            cursor = connection.cursor()

            #print("Database created and connected successfully!")

            sql_query = "SELECT * FROM music WHERE genre = '%s'" % genre

            cursor.execute(sql_query)

            #print(cursor.fetchall())

            output = cursor.fetchall()
            for row in output:
                print(row)


        #print("Database connection closed successfully!")
    except sqlite3.IntegrityError as e:
        print(f"Error: Integrity constraint violated - {e}")

    except sqlite3.OperationalError as e:
        print(f"Error: Operational issue - {e}")

    except sqlite3.Error as e:
        print(f"Error: Generic Sqlite3 error - {e}")        

    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %%
getAlbumByGenre('Rock')
# Out:
# (1, 1967, "Sgt. Pepper's Lonely Hearts Club Band", 'The Beatles', 'Rock', 'Rock & Roll, Psychedelic Rock', 0.0)
# (2, 1966, 'Pet Sounds', 'The Beach Boys', 'Rock', 'Pop Rock, Psychedelic Rock', 0.0)
# (3, 1966, 'Revolver', 'The Beatles', 'Rock', 'Psychedelic Rock, Pop Rock', 0.0)
# (4, 1965, 'Highway 61 Revisited', 'Bob Dylan', 'Rock', 'Folk Rock, Blues Rock', 0.0)
# (7, 1972, 'Exile on Main St.', 'The Rolling Stones', 'Rock', 'Blues Rock, Rock & Roll, Classic Rock', 0.0)
# (8, 1979, 'London Calling', 'The Clash', 'Rock', 'Punk, New Wave', 0.0)
# (10, 1968, 'The Beatles ("The White Album")', 'The Beatles', 'Rock', 'Rock & Roll, Pop Rock, Psychedelic Rock, Experimental', 0.0)
# (11, 1976, 'The Sun Sessions', 'Elvis Presley', 'Rock', 'Rock & Roll', 0.0)
# (13, 1967, 'The Velvet Underground & Nico', 'The Velvet Underground', 'Rock', 'Garage Rock, Art Rock, Experimental', 0.0)
# (14, 1969, 'Abbey Road', 'The Beatles', 'Rock', 'Psychedelic Rock, Classic Rock, Pop Rock', 0.0)
# ...

# %%
class Album(BaseModel):
    index: int = Field(description="The database index of the album")
    year: int = Field(description="The year the album was released")
    title: str = Field(description="The title of the album")
    artist: str = Field(description="The name of the artist who made the album")
    genre: str = Field(description="The music genre of the album")
    subgenre: str = Field(description="The music subgenre of the album")
    price: float = Field(description="The orice of the album")

class AlbumList(BaseModel):
    albums: list[Album]

# %%
class getAlbumByTitle(BaseModel):
    """Tool that queries albums by title and returns an Album object containing the database index, Album Year, Album Title, Artist Name, Album Genre, Album Subgenre  and Album Price"""
    albumTitle: str = Field(description="The title of the album.")

    def run(self):
        try:
            with sqlite3.connect('music.db') as connection:
                cursor = connection.cursor()

                sql_query = "SELECT * FROM music WHERE album = '%s'" % self.albumTitle

                cursor.execute(sql_query)
                result = cursor.fetchone()

                keys = ['index','year','title','artist','genre','subgenre','price']
                vals = list(result)

                result_dict = dict(zip(keys, vals))

                album = Album(**result_dict)

                


                return album


        #print("Database connection closed successfully!")
        except sqlite3.IntegrityError as e:
            print(f"Error: Integrity constraint violated - {e}")

        except sqlite3.OperationalError as e:
            print(f"Error: Operational issue - {e}")

        except sqlite3.Error as e:
            print(f"Error: Generic Sqlite3 error - {e}")        

        except Exception as e:
            print(f"An unexpected error occurred: {e}")

# %%
class getAlbumByArtist(BaseModel):
    """Tool that queries albums by Artist and returns a list of  Album objects containing the database index, Album Year, Album Title, Artist Name, Album Genre, Album Subgenre  and Album Price"""
    albumArtist: str = Field(description="The Artist name.")

    def run(self):
        try:
            with sqlite3.connect('music.db') as connection:
                cursor = connection.cursor()

                sql_query = "SELECT * FROM music WHERE artist = '%s'" % self.albumArtist

                cursor.execute(sql_query)
                results = cursor.fetchall()
                print(results)

                albums = []

                for result in results:
                    keys = ['index','year','title','artist','genre','subgenre','price']
                    vals = list(result)

                    result_dict = dict(zip(keys, vals))

                    album = Album(**result_dict)
                    albums.append(album)

                


                return albums


        #print("Database connection closed successfully!")
        except sqlite3.IntegrityError as e:
            print(f"Error: Integrity constraint violated - {e}")

        except sqlite3.OperationalError as e:
            print(f"Error: Operational issue - {e}")

        except sqlite3.Error as e:
            print(f"Error: Generic Sqlite3 error - {e}")        

        except Exception as e:
            print(f"An unexpected error occurred: {e}")

# %%
class getAlbumByYear(BaseModel):
    """Tool that queries albums by Year and returns a list of  Album objects containing the database index, Album Year, Album Title, Artist Name, Album Genre, Album Subgenre  and Album Price"""
    albumYear: str = Field(description="The Year.")

    def run(self):
        try:
            with sqlite3.connect('music.db') as connection:
                cursor = connection.cursor()

                sql_query = "SELECT * FROM music WHERE year = '%s'" % self.albumYear

                cursor.execute(sql_query)
                results = cursor.fetchall()

                albums = []

                for result in results:
                    keys = ['index','year','title','artist','genre','subgenre','price']
                    vals = list(result)

                    result_dict = dict(zip(keys, vals))

                    album = Album(**result_dict)
                    albums.append(album)

                


                return albums


        #print("Database connection closed successfully!")
        except sqlite3.IntegrityError as e:
            print(f"Error: Integrity constraint violated - {e}")

        except sqlite3.OperationalError as e:
            print(f"Error: Operational issue - {e}")

        except sqlite3.Error as e:
            print(f"Error: Generic Sqlite3 error - {e}")        

        except Exception as e:
            print(f"An unexpected error occurred: {e}")

# %%
class getAlbumByGenre(BaseModel):
    """Tool that queries albums by Genre and returns a list of  Album objects containing the database index, Album Year, Album Title, Artist Name, Album Genre, Album Subgenre  and Album Price"""
    albumGenre: str = Field(description="The Album Genre name.")

    def run(self):
        try:
            with sqlite3.connect('music.db') as connection:
                cursor = connection.cursor()

                sql_query = "SELECT * FROM music WHERE genre = '%s'" % self.albumGenre

                cursor.execute(sql_query)
                results = cursor.fetchall()
                print(results)

                albums = []

                for result in results:
                    keys = ['index','year','title','artist','genre','subgenre','price']
                    vals = list(result)

                    result_dict = dict(zip(keys, vals))

                    album = Album(**result_dict)
                    albums.append(album)

                


                return albums


        #print("Database connection closed successfully!")
        except sqlite3.IntegrityError as e:
            print(f"Error: Integrity constraint violated - {e}")

        except sqlite3.OperationalError as e:
            print(f"Error: Operational issue - {e}")

        except sqlite3.Error as e:
            print(f"Error: Generic Sqlite3 error - {e}")        

        except Exception as e:
            print(f"An unexpected error occurred: {e}")

# %%
# write function to execute tool. Take function name and parameters and return result of function
@traceable(name="AD Tool Call")
def execute_function(tool_call, tool_lookup):
    function_name = tool_call.function.name
    args = json.loads(tool_call.function.arguments)
    tool = tool_lookup[function_name](**args)
    return function_name, tool.run()

tools = [getAlbumByTitle, getAlbumByArtist, getAlbumByGenre, getAlbumByYear]
tool_lookup = {tool.__name__: tool for tool in tools}

# %% [markdown]
# ### Album by Title Workflow

# %%
@traceable(name="Albums By Title Workflow")
def albumTitleWorkflow(albumTitle: str):

 # message to read file
    messages = [
        {"role": "system", "content": "You are a useful music shop assistant that provides information on albums."},
        {"role": "user", "content": f"Please provide information on the following album title : {albumTitle}"}

    ]

    response = client.chat.completions.create (
    model=model,
    messages=messages,
    temperature=0,
    tools=[pydantic_function_tool(getAlbumByTitle)]
    )
    #print(response)

 # read the file
    #tool_name = response.choices[0].message.tool_calls[0].function.name
    tool_args = json.loads(response.choices[0].message.tool_calls[0].function.arguments)
    #print(tool_args)
    album = getAlbumByTitle(**tool_args).run()

#
    #messages = [
    #    {"role": "system", "content": "You are a useful music shop assistant that provides information on music albums using a given title"},
    #    {"role": "user", "content": "Please provide information on the following album: {content}".format(content=album_content)}
    #]
#
    #response = client.chat.completions.create (
    #model=model,
    #messages=messages,
    #temperature=0,
    #tools=[pydantic_function_tool(getAlbumByTitle)],
    #response_format=Album
    #)
#
    return album

# %%
res= albumTitleWorkflow('Nevermind')

# %%
res.title
# Out:
# 'Nevermind'

# %%
res
# Out:
# Album(index=17, year=1991, title='Nevermind', artist='Nirvana', genre='Rock', subgenre='Alternative Rock, Grunge', price=0.0)

# %% [markdown]
# ### Album by Artist Workflow

# %%
@traceable(name="Albums By Artist Workflow")
def albumArtistWorkflow(albumArtist: str):

 # message to read file
    messages = [
        {"role": "system", "content": "You are a useful music shop assistant that provides information on albums."},
        {"role": "user", "content": f"Please provide information on albums by the following artist : {albumArtist}"}

    ]

    response = client.chat.completions.create (
    model=model,
    messages=messages,
    temperature=0,
    tools=[pydantic_function_tool(getAlbumByArtist)]
    )
    print(response)

 # read the file
    #tool_name = response.choices[0].message.tool_calls[0].function.name
    tool_args = json.loads(response.choices[0].message.tool_calls[0].function.arguments)
    print(tool_args)
    albums = getAlbumByArtist(**tool_args).run()

#
    #messages = [
    #    {"role": "system", "content": "You are a useful music shop assistant that provides information on music albums using a given title"},
    #    {"role": "user", "content": "Please provide information on the following album: {content}".format(content=album_content)}
    #]
#
    #response = client.chat.completions.create (
    #model=model,
    #messages=messages,
    #temperature=0,
    #tools=[pydantic_function_tool(getAlbumByTitle)],
    #response_format=Album
    #)
#
    return albums

# %%
res= albumArtistWorkflow('The Beach Boys')
# Out:
# ChatCompletion(id='Bpj7aPSUCPeTvr0PwJuMgQ4', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='function-call-5131774106151896165', function=Function(arguments='{"albumArtist":"The Beach Boys"}', name='getAlbumByArtist'), type='function')]))], created=1761318918, model='gemini-2.5-flash-lite', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=19, prompt_tokens=104, total_tokens=123, completion_tokens_details=None, prompt_tokens_details=None))
# {'albumArtist': 'The Beach Boys'}

# %%
res
# Out:
# [Album(index=2, year=1966, title='Pet Sounds', artist='The Beach Boys', genre='Rock', subgenre='Pop Rock, Psychedelic Rock', price=0.0),
#  Album(index=271, year=1965, title='The Beach Boys Today!', artist='The Beach Boys', genre='Rock', subgenre='Pop Rock, Psychedelic Rock', price=0.0),
#  Album(index=381, year=2011, title='The Smile Sessions', artist='The Beach Boys', genre='Rock', subgenre='Pop Rock, Psychedelic Rock', price=0.0)]

# %% [markdown]
# ### Album by Year Workflow

# %%
@traceable(name="Albums By Year Workflow")
def albumYearWorkflow(albumYear: str):

 # message to read file
    messages = [
        {"role": "system", "content": "You are a useful music shop assistant that provides information on albums."},
        {"role": "user", "content": f"Please provide information on albums in the following year : {albumYear}"}

    ]

    response = client.chat.completions.create (
    model=model,
    messages=messages,
    temperature=0,
    tools=[pydantic_function_tool(getAlbumByYear)]
    )
    print(response)

 # read the file
    #tool_name = response.choices[0].message.tool_calls[0].function.name
    tool_args = json.loads(response.choices[0].message.tool_calls[0].function.arguments)
    #print(tool_args)
    albums = getAlbumByYear(**tool_args).run()

#
    #messages = [
    #    {"role": "system", "content": "You are a useful music shop assistant that provides information on music albums using a given title"},
    #    {"role": "user", "content": "Please provide information on the following album: {content}".format(content=album_content)}
    #]
#
    #response = client.chat.completions.create (
    #model=model,
    #messages=messages,
    #temperature=0,
    #tools=[pydantic_function_tool(getAlbumByTitle)],
    #response_format=Album
    #)
#
    return albums

# %%
res = albumYearWorkflow('1966')
res
# Out:
# ChatCompletion(id='DJ77aP-qG87Y1e8P2oLrwQQ', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='function-call-13675892452636176389', function=Function(arguments='{"albumYear":"1966"}', name='getAlbumByYear'), type='function')]))], created=1761320460, model='gemini-2.5-flash-lite', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=20, prompt_tokens=105, total_tokens=125, completion_tokens_details=None, prompt_tokens_details=None))
# [Album(index=2, year=1966, title='Pet Sounds', artist='The Beach Boys', genre='Rock', subgenre='Pop Rock, Psychedelic Rock', price=0.0),
#  Album(index=3, year=1966, title='Revolver', artist='The Beatles', genre='Rock', subgenre='Psychedelic Rock, Pop Rock', price=0.0),
# ...

# %% [markdown]
# ### Album by Genre Workflow

# %%
@traceable(name="Albums By Genre Workflow")
def albumGenreWorkflow(albumGenre: str):

 # message to read file
    messages = [
        {"role": "system", "content": "You are a useful music shop assistant that provides information on albums."},
        {"role": "user", "content": f"Please provide information on albums in the following genre : {albumGenre}"}

    ]

    response = client.chat.completions.create (
    model=model,
    messages=messages,
    temperature=0,
    tools=[pydantic_function_tool(getAlbumByGenre), pydantic_function_tool(getAlbumByTitle)]
    )
    print(response)

 # read the file
    tool_name = response.choices[0].message.tool_calls[0].function.name
    tool_args = json.loads(response.choices[0].message.tool_calls[0].function.arguments)
    print(f"Tool Args : { tool_args}")
    print(f"Tool Name : { tool_name}")
    albums = getAlbumByGenre(**tool_args).run()

#
    #messages = [
    #    {"role": "system", "content": "You are a useful music shop assistant that provides information on music albums using a given title"},
    #    {"role": "user", "content": "Please provide information on the following album: {content}".format(content=album_content)}
    #]
#
    #response = client.chat.completions.create (
    #model=model,
    #messages=messages,
    #temperature=0,
    #tools=[pydantic_function_tool(getAlbumByTitle)],
    #response_format=Album
    #)
#
    return albums

# %%
res = albumGenreWorkflow('Rock')
res
# Out:
# ChatCompletion(id='oqP7aPWEK7fd1e8PsMSz4AI', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='function-call-2520418352945750904', function=Function(arguments='{"albumGenre":"Rock"}', name='getAlbumByGenre'), type='function')]))], created=1761321890, model='gemini-2.5-flash-lite', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=17, prompt_tokens=178, total_tokens=195, completion_tokens_details=None, prompt_tokens_details=None))
# Tool Args : {'albumGenre': 'Rock'}
# Tool Name : getAlbumByGenre
# ...
